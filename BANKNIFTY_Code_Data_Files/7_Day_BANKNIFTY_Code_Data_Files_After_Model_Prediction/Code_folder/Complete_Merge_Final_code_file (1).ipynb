# %%
import pandas as pd
pd.set_option('display.max_columns',40)
import os
os.chdir("C:\\Users\\dell\\Desktop\\Ideal_Data\\Updated_Ideal_files")

# %%
# Path to your data folder in Google Drive
data_folder = "C:\\Users\\dell\\Desktop\\Ideal_Data\\Updated_Ideal_files"

# List files in the specified folder to confirm access
folder_path = os.path.join(data_folder)  # Update 'path_to_your_data_folder' with your actual folder path
file_list = os.listdir(folder_path)
file_list
# Out:
# ['Ideal_10%.csv',
#  'Ideal_100%.csv',
#  'Ideal_20%.csv',
#  'Ideal_5%.csv',
#  'Ideal_50%.csv',
#  'Ideal_80%.csv']

# %%
s = pd.read_csv('Ideal_5%.csv')
s1 = pd.read_csv('Ideal_10%.csv')
s2 = pd.read_csv('Ideal_20%.csv')
s3 = pd.read_csv('Ideal_50%.csv')
s4 = pd.read_csv('Ideal_80%.csv')
s5 = pd.read_csv('Ideal_100%.csv')

print(s.duplicated().sum())
print(s1.duplicated().sum())
print(s2.duplicated().sum())
print(s3.duplicated().sum())
print(s4.duplicated().sum())
print(s5.duplicated().sum())
# Out:
# 0
# 1
# 0
# 0
# 1
# 0

# %%
s1.drop_duplicates(keep='first',inplace=True)
s4.drop_duplicates(keep='first',inplace=True)
s5.drop_duplicates(keep='first',inplace=True)

# %%
print(s.duplicated().sum())
print(s1.duplicated().sum())
print(s2.duplicated().sum())
print(s3.duplicated().sum())
print(s4.duplicated().sum())
print(s5.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
s.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_5%_dis',
#        'Predicted_5%_dis', 'Actual_Ideal_Target', 'Predicted_Ideal_Target',
#        'Profit', 'Actual_ideal_profit', 'PIT_Profit_5', 'PIT_D_Profit_5',
#        'PIT_Loss_5', 'PIT_Defence_Target_5', 'PIT_Ideal_Target_5'],
#       dtype='object')

# %%
s.rename({'Actual_5%_dis':'Actual_5%_'},inplace=True,axis=1)
s.rename({'Predicted_5%_dis':'Predicted_5%_'},inplace=True,axis=1)

# %%
s.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_5%_', 'Predicted_5%_',
#        'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit', 'PIT_Profit_5', 'PIT_D_Profit_5', 'PIT_Loss_5',
#        'PIT_Defence_Target_5', 'PIT_Ideal_Target_5'],
#       dtype='object')

# %%
s.rename({'Actual_ideal_profit':'Actual_ideal_profit_5'},inplace=True,axis=1)
s1.rename({'Actual_ideal_profit':'Actual_ideal_profit_10'},inplace=True,axis=1)
s2.rename({'Actual_ideal_profit':'Actual_ideal_profit_20'},inplace=True,axis=1)
s3.rename({'Actual_ideal_profit':'Actual_ideal_profit_50'},inplace=True,axis=1)
s4.rename({'Actual_ideal_profit':'Actual_ideal_profit_80'},inplace=True,axis=1)
s5.rename({'Actual_ideal_profit':'Actual_ideal_profit_100'},inplace=True,axis=1)

# %%
s5.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_100%_', 'Predicted_100%_',
#        'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit_100', 'PIT_Profit_100', 'PIT_D_Profit_100',
#        'PIT_Loss_100', 'PIT_Defence_Target_100', 'PIT_Ideal_Target_100'],
#       dtype='object')

# %%
s4.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_80%_', 'Predicted_80%_',
#        'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit_80', 'PIT_Profit_80', 'PIT_D_Profit_80',
#        'PIT_Loss_80', 'PIT_Defence_Target_80', 'PIT_Ideal_Target_80'],
#       dtype='object')

# %%
s3.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_50%_', 'Predicted_50%_',
#        'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit_50', 'PIT_Profit_50', 'PIT_D_Profit_50',
#        'PIT_Loss_50', 'PIT_Defence_Target_50', 'PIT_Ideal_Target_50'],
#       dtype='object')

# %%
print(s.shape)
print(s1.shape)
print(s2.shape)
print(s3.shape)
print(s4.shape)
print(s5.shape)
# Out:
# (2720, 32)
# (2720, 32)
# (2720, 32)
# (2720, 32)
# (2720, 32)
# (2720, 32)

# %%
# Columns to remove
columns_to_remove = [
    'Open', 'High', 'Low', 'Close', 'SellersLevel4',
    'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
    'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
    'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
    'Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target_Agressive'
]

s1.drop(columns=columns_to_remove, inplace=True, errors='ignore')
s2.drop(columns=columns_to_remove, inplace=True, errors='ignore')
s3.drop(columns=columns_to_remove, inplace=True, errors='ignore')
s4.drop(columns=columns_to_remove, inplace=True, errors='ignore')
s5.drop(columns=columns_to_remove, inplace=True, errors='ignore')

# %%
# Columns to remove
columns_to_remove_0 = ['Actual_5%_',
       'Predicted_5%_','PIT_Defence_Target_5', 
       'PIT_Ideal_Target_5']


# Columns to remove
columns_to_remove_1 = ['Actual_10%_',
       'Predicted_10%_','PIT_Defence_Target_10', 
       'PIT_Ideal_Target_10']

# Columns to remove
columns_to_remove_2 = ['Actual_20%_',
       'Predicted_20%_','PIT_Defence_Target_20', 
       'PIT_Ideal_Target_20']

# # Columns to remove
columns_to_remove_3 = ['Actual_50%_',
       'Predicted_50%_','PIT_Defence_Target_50', 
       'PIT_Ideal_Target_50']

# Columns to remove
columns_to_remove_4 = ['Actual_80%_',
       'Predicted_80%_','PIT_Defence_Target_80', 
       'PIT_Ideal_Target_80']


# Columns to remove
columns_to_remove_5 = ['Actual_100%_',
       'Predicted_100%_','PIT_Defence_Target_100', 
       'PIT_Ideal_Target_100']


s.drop(columns=columns_to_remove_0, inplace=True, errors='ignore')
s1.drop(columns=columns_to_remove_1, inplace=True, errors='ignore')
s2.drop(columns=columns_to_remove_2, inplace=True, errors='ignore')
s3.drop(columns=columns_to_remove_3, inplace=True, errors='ignore')
s4.drop(columns=columns_to_remove_4, inplace=True, errors='ignore')
s5.drop(columns=columns_to_remove_5, inplace=True, errors='ignore')

# %%
print(s.columns)
print(s1.columns)
print(s2.columns)
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_Ideal_Target',
#        'Predicted_Ideal_Target', 'Profit', 'Actual_ideal_profit_5',
#        'PIT_Profit_5', 'PIT_D_Profit_5', 'PIT_Loss_5'],
#       dtype='object')
# Index(['Time Stamp', 'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit_10', 'PIT_Profit_10', 'PIT_D_Profit_10',
#        'PIT_Loss_10'],
#       dtype='object')
# Index(['Time Stamp', 'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit_20', 'PIT_Profit_20', 'PIT_D_Profit_20',
#        'PIT_Loss_20'],
#       dtype='object')

# %%
print(s3.columns)
print(s4.columns)
print(s5.columns)
# Out:
# Index(['Time Stamp', 'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit_50', 'PIT_Profit_50', 'PIT_D_Profit_50',
#        'PIT_Loss_50'],
#       dtype='object')
# Index(['Time Stamp', 'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit_80', 'PIT_Profit_80', 'PIT_D_Profit_80',
#        'PIT_Loss_80'],
#       dtype='object')
# Index(['Time Stamp', 'Actual_Ideal_Target', 'Predicted_Ideal_Target', 'Profit',
#        'Actual_ideal_profit_100', 'PIT_Profit_100', 'PIT_D_Profit_100',
#        'PIT_Loss_100'],
#       dtype='object')

# %%
# Check the number of unique values in the 'Time Stamp' column for each DataFrame
unique_count_df1 = s['Time Stamp'].nunique()
unique_count_df2 = s1['Time Stamp'].nunique()
unique_count_df3 = s2['Time Stamp'].nunique()
unique_count_df4 = s3['Time Stamp'].nunique()
unique_count_df5 = s4['Time Stamp'].nunique()
unique_count_df6 = s5['Time Stamp'].nunique()

# Print the number of unique values in the 'Time Stamp' column for each DataFrame
print(f"Unique values in 'Time Stamp' for df1: {unique_count_df1}")
print(f"Unique values in 'Time Stamp' for df2: {unique_count_df2}")
print(f"Unique values in 'Time Stamp' for df3: {unique_count_df3}")
print(f"Unique values in 'Time Stamp' for df4: {unique_count_df4}")
print(f"Unique values in 'Time Stamp' for df5: {unique_count_df5}")
print(f"Unique values in 'Time Stamp' for df5: {unique_count_df6}")
# Out:
# Unique values in 'Time Stamp' for df1: 2711
# Unique values in 'Time Stamp' for df2: 2711
# Unique values in 'Time Stamp' for df3: 2711
# Unique values in 'Time Stamp' for df4: 2711
# Unique values in 'Time Stamp' for df5: 2711
# Unique values in 'Time Stamp' for df5: 2711

# %%
dataframes = [s, s1, s2,s3,s4,s5]

# Function to convert 'Time Stamp' to datetime
def convert_to_datetime(df):
    df['Time Stamp'] = pd.to_datetime(df['Time Stamp'])
    return df

# Function to rename columns to ensure uniqueness
def rename_columns(df, suffix):
    return df.rename(columns=lambda x: x if x == 'Time Stamp' else f'{x}_{suffix}')

# Convert 'Time Stamp' to datetime in each DataFrame
dataframes = [convert_to_datetime(df) for df in dataframes]

# Rename columns in each DataFrame to ensure unique names
renamed_dataframes = [rename_columns(df, i) for i, df in enumerate(dataframes)]

# Merge DataFrames on 'Time Stamp'
merged_df = renamed_dataframes[0]

for df in renamed_dataframes[1:]:
    merged_df = pd.merge(merged_df, df, on='Time Stamp', how='inner')

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open_0', 'High_0', 'Low_0', 'Close_0', 'SellersLevel4_0',
#        'SellersLevel3_0', 'SellersLevel2_0', 'SellersLevel1_0',
#        'SellersLevel0_0', 'BuyersLevel0_0', 'BuyersLevel1_0', 'BuyersLevel2_0',
#        'BuyersLevel3_0', 'BuyersLevel4_0', 'BuyersInControlPrice_0',
#        'SellersInControlPrice_0', 'Entry_0', 'Defence_0', 'Stop_0', 'Target_0',
#        'Actual_Ideal_Target_0', 'Predicted_Ideal_Target_0', 'Profit_0',
#        'Actual_ideal_profit_5_0', 'PIT_Profit_5_0', 'PIT_D_Profit_5_0',
#        'PIT_Loss_5_0', 'Actual_Ideal_Target_1', 'Predicted_Ideal_Target_1',
#        'Profit_1', 'Actual_ideal_profit_10_1', 'PIT_Profit_10_1',
#        'PIT_D_Profit_10_1', 'PIT_Loss_10_1', 'Actual_Ideal_Target_2',
#        'Predicted_Ideal_Target_2', 'Profit_2', 'Actual_ideal_profit_20_2',
#        'PIT_Profit_20_2', 'PIT_D_Profit_20_2', 'PIT_Loss_20_2',
#        'Actual_Ideal_Target_3', 'Predicted_Ideal_Target_3', 'Profit_3',
# ...

# %%
merged_df.rename({'Actual_Ideal_Target_0':'Target_Actual_Ideal_5','Predicted_Ideal_Target_0':'Target_Predicted_Ideal_5'},inplace=True,axis=1)
merged_df.rename({'Actual_Ideal_Target_1':'Target_Actual_Ideal_10','Predicted_Ideal_Target_1':'Target_Predicted_Ideal_10'},inplace=True,axis=1)
merged_df.rename({'Actual_Ideal_Target_2':'Target_Actual_Ideal_20','Predicted_Ideal_Target_2':'Target_Predicted_Ideal_20'},inplace=True,axis=1)
merged_df.rename({'Actual_Ideal_Target_3':'Target_Actual_Ideal_50','Predicted_Ideal_Target_3':'Target_Predicted_Ideal_50'},inplace=True,axis=1)
merged_df.rename({'Actual_Ideal_Target_4':'Target_Actual_Ideal_80','Predicted_Ideal_Target_4':'Target_Predicted_Ideal_80'},inplace=True,axis=1)
merged_df.rename({'Actual_Ideal_Target_5':'Target_Actual_Ideal_100','Predicted_Ideal_Target_5':'Target_Predicted_Ideal_100'},inplace=True,axis=1)

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open_0', 'High_0', 'Low_0', 'Close_0', 'SellersLevel4_0',
#        'SellersLevel3_0', 'SellersLevel2_0', 'SellersLevel1_0',
#        'SellersLevel0_0', 'BuyersLevel0_0', 'BuyersLevel1_0', 'BuyersLevel2_0',
#        'BuyersLevel3_0', 'BuyersLevel4_0', 'BuyersInControlPrice_0',
#        'SellersInControlPrice_0', 'Entry_0', 'Defence_0', 'Stop_0', 'Target_0',
#        'Target_Actual_Ideal_5', 'Target_Predicted_Ideal_5', 'Profit_0',
#        'Actual_ideal_profit_5_0', 'PIT_Profit_5_0', 'PIT_D_Profit_5_0',
#        'PIT_Loss_5_0', 'Target_Actual_Ideal_10', 'Target_Predicted_Ideal_10',
#        'Profit_1', 'Actual_ideal_profit_10_1', 'PIT_Profit_10_1',
#        'PIT_D_Profit_10_1', 'PIT_Loss_10_1', 'Target_Actual_Ideal_20',
#        'Target_Predicted_Ideal_20', 'Profit_2', 'Actual_ideal_profit_20_2',
#        'PIT_Profit_20_2', 'PIT_D_Profit_20_2', 'PIT_Loss_20_2',
#        'Target_Actual_Ideal_50', 'Target_Predicted_Ideal_50', 'Profit_3',
# ...

# %%
# Columns to remove
columns_to_remove_5 = ['Profit_1',
       'Profit_2','Profit_3', 'Profit_4',
       'Profit_5']

merged_df.drop(columns=columns_to_remove_5, inplace=True, errors='ignore')

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open_0', 'High_0', 'Low_0', 'Close_0', 'SellersLevel4_0',
#        'SellersLevel3_0', 'SellersLevel2_0', 'SellersLevel1_0',
#        'SellersLevel0_0', 'BuyersLevel0_0', 'BuyersLevel1_0', 'BuyersLevel2_0',
#        'BuyersLevel3_0', 'BuyersLevel4_0', 'BuyersInControlPrice_0',
#        'SellersInControlPrice_0', 'Entry_0', 'Defence_0', 'Stop_0', 'Target_0',
#        'Target_Actual_Ideal_5', 'Target_Predicted_Ideal_5', 'Profit_0',
#        'Actual_ideal_profit_5_0', 'PIT_Profit_5_0', 'PIT_D_Profit_5_0',
#        'PIT_Loss_5_0', 'Target_Actual_Ideal_10', 'Target_Predicted_Ideal_10',
#        'Actual_ideal_profit_10_1', 'PIT_Profit_10_1', 'PIT_D_Profit_10_1',
#        'PIT_Loss_10_1', 'Target_Actual_Ideal_20', 'Target_Predicted_Ideal_20',
#        'Actual_ideal_profit_20_2', 'PIT_Profit_20_2', 'PIT_D_Profit_20_2',
#        'PIT_Loss_20_2', 'Target_Actual_Ideal_50', 'Target_Predicted_Ideal_50',
# ...

# %%
import pandas as pd

# Function to remove '_0' from column names
def remove_suffix(columns, suffix='_0'):
    return [col.replace(suffix, '') for col in columns]

# Assuming Merged_df_loss is your dataframe
# Apply the function to the dataframe's column names
updated_columns = remove_suffix(merged_df.columns)

# Update the dataframe with the new column names
merged_df.columns = updated_columns

# Display the updated column names
print(merged_df.columns)
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Ideal_5',
#        'Target_Predicted_Ideal_5', 'Profit', 'Actual_ideal_profit_5',
#        'PIT_Profit_5', 'PIT_D_Profit_5', 'PIT_Loss_5',
#        'Target_Actual_Ideal_10', 'Target_Predicted_Ideal_10',
#        'Actual_ideal_profit_10_1', 'PIT_Profit_10_1', 'PIT_D_Profit_10_1',
#        'PIT_Loss_10_1', 'Target_Actual_Ideal_20', 'Target_Predicted_Ideal_20',
#        'Actual_ideal_profit_20_2', 'PIT_Profit_20_2', 'PIT_D_Profit_20_2',
#        'PIT_Loss_20_2', 'Target_Actual_Ideal_50', 'Target_Predicted_Ideal_50',
#        'Actual_ideal_profit_50_3', 'PIT_Profit_50_3', 'PIT_D_Profit_50_3',
# ...

# %%
merged_df.rename({'Actual_ideal_profit_10_1':'Actual_ideal_profit_10','PIT_Profit_10_1':'PIT_Profit_10','PIT_D_Profit_10_1':'PIT_D_Profit_10','PIT_Loss_10_1':'PIT_Loss_10'},inplace=True,axis=1)
merged_df.rename({'Actual_ideal_profit_20_2':'Actual_ideal_profit_20','PIT_Profit_20_2':'PIT_Profit_20','PIT_D_Profit_20_2':'PIT_D_Profit_20','PIT_Loss_20_2':'PIT_Loss_20'},inplace=True,axis=1)
merged_df.rename({'Actual_ideal_profit_50_3':'Actual_ideal_profit_50','PIT_Profit_50_3':'PIT_Profit_50','PIT_D_Profit_50_3':'PIT_D_Profit_50','PIT_Loss_50_3':'PIT_Loss_50'},inplace=True,axis=1)
merged_df.rename({'Actual_ideal_profit_80_4':'Actual_ideal_profit_80','PIT_Profit_80_4':'PIT_Profit_80','PIT_D_Profit_80_4':'PIT_D_Profit_80','PIT_Loss_80_4':'PIT_Loss_80'},inplace=True,axis=1)
merged_df.rename({ 'Actual_ideal_profit_100_5': 'Actual_ideal_profit_100','PIT_Profit_100_5':'PIT_Profit_100','PIT_D_Profit_100_5':'PIT_D_Profit_100','PIT_Loss_100_5':'PIT_Loss_100'},inplace=True,axis=1)

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Ideal_5',
#        'Target_Predicted_Ideal_5', 'Profit', 'Actual_ideal_profit_5',
#        'PIT_Profit_5', 'PIT_D_Profit_5', 'PIT_Loss_5',
#        'Target_Actual_Ideal_10', 'Target_Predicted_Ideal_10',
#        'Actual_ideal_profit_10', 'PIT_Profit_10', 'PIT_D_Profit_10',
#        'PIT_Loss_10', 'Target_Actual_Ideal_20', 'Target_Predicted_Ideal_20',
#        'Actual_ideal_profit_20', 'PIT_Profit_20', 'PIT_D_Profit_20',
#        'PIT_Loss_20', 'Target_Actual_Ideal_50', 'Target_Predicted_Ideal_50',
#        'Actual_ideal_profit_50', 'PIT_Profit_50', 'PIT_D_Profit_50',
# ...

# %%
#  merged_df.columns = merged_df.columns.str.replace(r'(_\d+)$', '', regex=True)

# %%
#  merged_df.columns

# %% [markdown]
# For Calculate Actual_Loss and Actual_Profit

# %%
import pandas as pd
from tqdm import tqdm
import os

def apply_trading_logic(df):
    # Initialize the new columns with 0
    df['T_Profit'] = 0
    df['D_Profit'] = 0
    df['Loss'] = 0
    df['Ideal_Target_Buyer'] = 0
    df['Defence_Target_Buyer'] = 0
    df['Ideal_Target_Seller'] = 0
    df['Defence_Target_Seller'] = 0

    # Iterate over each row with tqdm for progress tracking
    for i in tqdm(range(len(df))):
        row = df.iloc[i]

        # Entry Value Check
        if row['Entry'] != 0:
            entry = row['Entry']
            defence = row['Defence']

            # Buyers Logic
            if row['BuyersInControlPrice'] != 0:
                # Defence Check
                low_future_rows = df.iloc[i+1:]['Low']
                matched_low_index = low_future_rows[low_future_rows == defence].index
                if not matched_low_index.empty:
                    matched_low_index = matched_low_index[0]
                    max_high = df.loc[i:matched_low_index, 'High'].max()
                    max_close = df.loc[i:matched_low_index, 'Close'].max()

                    df.loc[i, 'Ideal_Target_Buyer'] = max_close
                    # df.loc[i, 'Ideal_Target_Agressive'] = max_high

                    # Target vs. Max High Value Comparison
                    if row['Target'] <= max_high:
                        df.loc[i, 'T_Profit'] = row['Target'] - entry
                    else:
                        stop = row['Stop']
                        if stop != 0:
                            df.loc[i, 'Defence_Target_Buyer'] = ((entry + defence) / 2) + 0.25
                            matched_stop_index = low_future_rows[low_future_rows == stop].index
                            if not matched_stop_index.empty:
                                matched_stop_index = matched_stop_index[0]
                                max_high_stop = df.loc[i:matched_stop_index, 'High'].max()
                                max_close_stop = df.loc[i:matched_stop_index, 'Close'].max()

                                # Defence Target vs. Max High Value Comparison
                                if df.loc[i, 'Defence_Target_Buyer'] <= max_high_stop:
                                    df.loc[i, 'D_Profit'] = df.loc[i, 'Defence_Target_Buyer'] - entry
                                else:
                                    df.loc[i, 'Loss'] = df.loc[i, 'Defence_Target_Buyer'] - entry

            # Sellers Logic
            if row['SellersInControlPrice'] != 0:
                # Defence Check
                high_future_rows = df.iloc[i+1:]['High']
                matched_high_index = high_future_rows[high_future_rows == defence].index
                if not matched_high_index.empty:
                    matched_high_index = matched_high_index[0]
                    min_low = df.loc[i:matched_high_index, 'Low'].min()
                    min_close = df.loc[i:matched_high_index, 'Close'].min()

                    df.loc[i, 'Ideal_Target_Seller'] = min_close
                    # df.loc[i, 'Ideal_Target_Agressive'] = min_low

                    # Target vs. Min Low Value Comparison
                    if row['Target'] >= min_low:
                        df.loc[i, 'T_Profit'] = entry - row['Target']
                    else:
                        stop = row['Stop']
                        if stop != 0:
                            df.loc[i, 'Defence_Target_Seller'] = ((entry + defence) / 2) - 0.25
                            matched_stop_index = high_future_rows[high_future_rows == stop].index
                            if not matched_stop_index.empty:
                                matched_stop_index = matched_stop_index[0]
                                min_low_stop = df.loc[i:matched_stop_index, 'Low'].min()
                                min_close_stop = df.loc[i:matched_stop_index, 'Close'].min()

                                # Defence Target vs. Min Low Value Comparison
                                if df.loc[i, 'Defence_Target_Seller'] >= min_low_stop:
                                    df.loc[i, 'D_Profit'] = entry - df.loc[i, 'Defence_Target_Seller']
                                else:
                                    df.loc[i, 'Loss'] = df.loc[i, 'Defence_Target_Seller'] - entry

        # Additional Calculations
        # df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
        # df.loc[i, 'Defence_Target'] = df.loc[i, 'Defence_Target_Buyer'] + df.loc[i, 'Defence_Target_Seller']

    # Drop unnecessary columns if they exist
    columns_to_drop = ["Ideal_Target_Buyer", "Ideal_Target_Seller", "Defence_Target_Buyer", "Defence_Target_Seller"]
    df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

    return df

# %%
merged_df = apply_trading_logic(merged_df)
# Out:
#   0%|          | 0/3216 [00:00<?, ?it/s]
# C:\Users\dell\AppData\Local\Temp\ipykernel_7088\3670551770.py:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5639.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target_Seller'] = min_close
# C:\Users\dell\AppData\Local\Temp\ipykernel_7088\3670551770.py:71: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'T_Profit'] = entry - row['Target']
# ...

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Ideal_5',
#        'Target_Predicted_Ideal_5', 'Profit', 'Actual_ideal_profit_5',
#        'PIT_Profit_5', 'PIT_D_Profit_5', 'PIT_Loss_5',
#        'Target_Actual_Ideal_10', 'Target_Predicted_Ideal_10',
#        'Actual_ideal_profit_10', 'PIT_Profit_10', 'PIT_D_Profit_10',
#        'PIT_Loss_10', 'Target_Actual_Ideal_20', 'Target_Predicted_Ideal_20',
#        'Actual_ideal_profit_20', 'PIT_Profit_20', 'PIT_D_Profit_20',
#        'PIT_Loss_20', 'Target_Actual_Ideal_50', 'Target_Predicted_Ideal_50',
#        'Actual_ideal_profit_50', 'PIT_Profit_50', 'PIT_D_Profit_50',
# ...

# %%
merged_df.drop(columns=['D_Profit'],axis=1,inplace=True)
merged_df.rename(columns={"T_Profit":"Actual_Profit","Loss":"Actual_Loss"},inplace=True)
merged_df.columns = merged_df.columns.str.replace('_dis', '', regex=False)

# Step 3: Rename columns with prefix 'PIT' to 'Predicted'
merged_df.columns = merged_df.columns.str.replace('PIT', 'Predicted_Ideal', regex=False)

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Ideal_5',
#        'Target_Predicted_Ideal_5', 'Profit', 'Actual_ideal_profit_5',
#        'Predicted_Ideal_Profit_5', 'Predicted_Ideal_D_Profit_5',
#        'Predicted_Ideal_Loss_5', 'Target_Actual_Ideal_10',
#        'Target_Predicted_Ideal_10', 'Actual_ideal_profit_10',
#        'Predicted_Ideal_Profit_10', 'Predicted_Ideal_D_Profit_10',
#        'Predicted_Ideal_Loss_10', 'Target_Actual_Ideal_20',
#        'Target_Predicted_Ideal_20', 'Actual_ideal_profit_20',
#        'Predicted_Ideal_Profit_20', 'Predicted_Ideal_D_Profit_20',
#        'Predicted_Ideal_Loss_20', 'Target_Actual_Ideal_50',
# ...

# %%
# merged_df.rename({'Target_Actual_Ideal':'Target_Actual_Ideal_5','Target_Predicted_Ideal':'Target_Predicted_Ideal_5'},inplace=True,axis=1)

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Ideal_5',
#        'Target_Predicted_Ideal_5', 'Profit', 'Actual_ideal_profit_5',
#        'Predicted_Ideal_Profit_5', 'Predicted_Ideal_D_Profit_5',
#        'Predicted_Ideal_Loss_5', 'Target_Actual_Ideal_10',
#        'Target_Predicted_Ideal_10', 'Actual_ideal_profit_10',
#        'Predicted_Ideal_Profit_10', 'Predicted_Ideal_D_Profit_10',
#        'Predicted_Ideal_Loss_10', 'Target_Actual_Ideal_20',
#        'Target_Predicted_Ideal_20', 'Actual_ideal_profit_20',
#        'Predicted_Ideal_Profit_20', 'Predicted_Ideal_D_Profit_20',
#        'Predicted_Ideal_Loss_20', 'Target_Actual_Ideal_50',
# ...

# %%
# merged_df.rename({'Actual_ideal_profit':'Actual_ideal_profit_5','Predicted_Ideal_Profit':'Predicted_Ideal_Profit_5'},inplace=True,axis=1)

# %%
# merged_df.columns

# %%
import pandas as pd

# Step 1: Rearrange columns in the desired order
desired_order = ['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
       'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
       'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
       'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
       'Entry', 'Defence', 'Stop', 'Target','Actual_Profit', 'Actual_Loss','Actual_ideal_profit_100', 'Predicted_Ideal_Profit_100','Target_Actual_Ideal_5',
       'Target_Predicted_Ideal_5', 'Profit', 'Actual_ideal_profit_5',
       'Predicted_Ideal_Profit_5', 'Predicted_Ideal_D_Profit_5',
       'Predicted_Ideal_Loss_5', 'Target_Actual_Ideal_10',
       'Target_Predicted_Ideal_10', 'Actual_ideal_profit_10',
       'Predicted_Ideal_Profit_10', 'Predicted_Ideal_D_Profit_10',
       'Predicted_Ideal_Loss_10', 'Target_Actual_Ideal_20',
       'Target_Predicted_Ideal_20', 'Actual_ideal_profit_20',
       'Predicted_Ideal_Profit_20', 'Predicted_Ideal_D_Profit_20',
       'Predicted_Ideal_Loss_20', 'Target_Actual_Ideal_50',
       'Target_Predicted_Ideal_50', 'Actual_ideal_profit_50',
       'Predicted_Ideal_Profit_50', 'Predicted_Ideal_D_Profit_50',
       'Predicted_Ideal_Loss_50', 'Target_Actual_Ideal_80',
       'Target_Predicted_Ideal_80', 'Actual_ideal_profit_80',
       'Predicted_Ideal_Profit_80', 'Predicted_Ideal_D_Profit_80',
       'Predicted_Ideal_Loss_80', 'Target_Actual_Ideal_100',
       'Target_Predicted_Ideal_100', 'Predicted_Ideal_D_Profit_100',
       'Predicted_Ideal_Loss_100']
       

# Reorder DataFrame columns
merged_df = merged_df[desired_order]

# %%
# merged_df.columns = merged_df.columns.str.replace('Target_Actual', 'Target_Ideal_Actual', regex=False)
# merged_df.columns = merged_df.columns.str.replace('Target_Predicted', 'Target_Ideal_Predicted', regex=False)

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_Profit', 'Actual_Loss',
#        'Actual_ideal_profit_100', 'Predicted_Ideal_Profit_100',
#        'Target_Actual_Ideal_5', 'Target_Predicted_Ideal_5', 'Profit',
#        'Actual_ideal_profit_5', 'Predicted_Ideal_Profit_5',
#        'Predicted_Ideal_D_Profit_5', 'Predicted_Ideal_Loss_5',
#        'Target_Actual_Ideal_10', 'Target_Predicted_Ideal_10',
#        'Actual_ideal_profit_10', 'Predicted_Ideal_Profit_10',
#        'Predicted_Ideal_D_Profit_10', 'Predicted_Ideal_Loss_10',
#        'Target_Actual_Ideal_20', 'Target_Predicted_Ideal_20',
#        'Actual_ideal_profit_20', 'Predicted_Ideal_Profit_20',
# ...

# %%
merged_df.drop(columns=['Profit'],inplace=True,axis=1)

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_Profit', 'Actual_Loss',
#        'Actual_ideal_profit_100', 'Predicted_Ideal_Profit_100',
#        'Target_Actual_Ideal_5', 'Target_Predicted_Ideal_5',
#        'Actual_ideal_profit_5', 'Predicted_Ideal_Profit_5',
#        'Predicted_Ideal_D_Profit_5', 'Predicted_Ideal_Loss_5',
#        'Target_Actual_Ideal_10', 'Target_Predicted_Ideal_10',
#        'Actual_ideal_profit_10', 'Predicted_Ideal_Profit_10',
#        'Predicted_Ideal_D_Profit_10', 'Predicted_Ideal_Loss_10',
#        'Target_Actual_Ideal_20', 'Target_Predicted_Ideal_20',
#        'Actual_ideal_profit_20', 'Predicted_Ideal_Profit_20',
# ...

# %%
merged_df.shape
# Out:
# (3216, 59)

# %%
merged_df.to_csv("C:\\Users\\dell\\Desktop\\Ideal_Data\\Merged_ideal\\Merged_Ideal2.csv",index=False)

# %%
s= pd.read_csv("C:\\Users\\dell\\Desktop\\Ideal_Data\\Merged_ideal\\Merged_Ideal2.csv")

# %%
s.duplicated().sum()
# Out:
# 0

# %%
s.shape
# Out:
# (3216, 59)

# %%
s.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_Profit', 'Actual_Loss',
#        'Actual_ideal_profit_100', 'Predicted_Ideal_Profit_100',
#        'Target_Actual_Ideal_5', 'Target_Predicted_Ideal_5',
#        'Actual_ideal_profit_5', 'Predicted_Ideal_Profit_5',
#        'Predicted_Ideal_D_Profit_5', 'Predicted_Ideal_Loss_5',
#        'Target_Actual_Ideal_10', 'Target_Predicted_Ideal_10',
#        'Actual_ideal_profit_10', 'Predicted_Ideal_Profit_10',
#        'Predicted_Ideal_D_Profit_10', 'Predicted_Ideal_Loss_10',
#        'Target_Actual_Ideal_20', 'Target_Predicted_Ideal_20',
#        'Actual_ideal_profit_20', 'Predicted_Ideal_Profit_20',
# ...

# %%
s.duplicated().sum()
# Out:
# 0

# %%
s.shape
# Out:
# (3216, 59)

# %% [markdown]
# **AGGRESSIVE**

# %%
import pandas as pd
pd.set_option('display.max_columns',40)
import os
os.chdir("C:\\Users\\dell\\Desktop\\Model Analysis\\Model_Analysis_Agressive_Prediction")

# %%
# Path to your data folder in Google Drive
data_folder = "C:\\Users\\dell\\Desktop\\Model Analysis\\Model_Analysis_Agressive_Prediction"

# List files in the specified folder to confirm access
folder_path = os.path.join(data_folder)  # Update 'path_to_your_data_folder' with your actual folder path
file_list = os.listdir(folder_path)
file_list
# Out:
# ['Processed_100_Processed_100%_Updated_RF_Agressive_100%_results (1).csv',
#  'Processed_10_Processed_10%_Updated_RF_Agressive_10%_results (1).csv',
#  'Processed_20_Processed_20%_Updated_RF_Agressive_20%_results (1).csv',
#  'Processed_50_Processed_50%_Updated_RF_Agressive_50%_results (1).csv',
#  'Processed_5_Processed_5%_Updated_RF_Agressive_5%_results (1).csv',
#  'Processed_80_Processed_80%_Updated_RF_Agressive_80%_results (1).csv']

# %%
s = pd.read_csv("Processed_5_Processed_5%_Updated_RF_Agressive_5%_results (1).csv")
s1 = pd.read_csv("Processed_10_Processed_10%_Updated_RF_Agressive_10%_results (1).csv")
s2 = pd.read_csv("Processed_20_Processed_20%_Updated_RF_Agressive_20%_results (1).csv")
s3 = pd.read_csv("Processed_50_Processed_50%_Updated_RF_Agressive_50%_results (1).csv")
s4 = pd.read_csv("Processed_80_Processed_80%_Updated_RF_Agressive_80%_results (1).csv")
s5 = pd.read_csv("Processed_100_Processed_100%_Updated_RF_Agressive_100%_results (1).csv")

# %%
print(s4.columns)
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_Agressive_80%_dis',
#        'Predicted_Agressive_80%_dis', 'Target_Actual_Agressive_80_dis',
#        'Predicted_Agressive_80_dis', 'Profit',
#        'Profit_80_Actual_Aggressive_Target', 'PAT_Profit_80',
#        'PAT_D_Profit_80', 'Target_Predicted_Aggressive_80_Loss',
#        'Target_Predicted_Aggressive_80_Defence_Target',
#        'Target_Predicted_Aggressive_80_Aggresive_T',
#        'Target_Predicted_Aggressive_80_Ideal_T'],
#       dtype='object')

# %%
s = pd.read_csv("Processed_5_Processed_5%_Updated_RF_Agressive_5%_results (1).csv")

# %%
print(s.columns)
print(s1.columns)
print(s2.columns)
print(s3.columns)
print(s4.columns)
print(s5.columns)
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_Agressive_5%_dis',
#        'Predicted_Agressive_5%_dis', 'Target_Actual_Agressive_5_dis',
#        'Predicted_Agressive_5_dis', 'Profit',
#        'Profit_5_Actual_Aggressive_Target', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss',
#        'Target_Predicted_Aggressive_5_Defence_Target',
#        'Target_Predicted_Aggressive_5_Aggresive_T',
#        'Target_Predicted_Aggressive_5_Ideal_T'],
#       dtype='object')
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
# ...

# %%
# # Columns to remove
# columns_to_remove_0 = ['Actual_Agressive_5%_dis',
#        'Predicted_Agressive_5%_dis','Target_Predicted_Aggressive_5_Defence_Target',
#        'Target_Predicted_Aggressive_5_Aggresive_T',
#        'Target_Predicted_Aggressive_5_Ideal_T']

# %%
# Columns to remove
# Columns to remove
columns_to_remove_0 = ['Actual_Agressive_5%_dis',
       'Predicted_Agressive_5%_dis','Target_Predicted_Aggressive_5_Defence_Target',
       'Target_Predicted_Aggressive_5_Aggresive_T',
       'Target_Predicted_Aggressive_5_Ideal_T']


columns_to_remove_1 = ['Actual_Agressive_10%_dis',
       'Predicted_Agressive_10%_dis','Target_Predicted_Aggressive_10_Defence_Target',
       'Target_Predicted_Aggressive_10_Aggresive_T',
       'Target_Predicted_Aggressive_10_Ideal_T']

# Columns to remove
columns_to_remove_2 = ['Actual_Agressive_20%_dis',
       'Predicted_Agressive_20%_dis','Target_Predicted_Aggressive_20_Defence_Target',
       'Target_Predicted_Aggressive_20_Aggresive_T',
       'Target_Predicted_Aggressive_20_Ideal_T']

# Columns to remove
columns_to_remove_3= ['Actual_Agressive_50%_dis',
       'Predicted_Agressive_50%_dis','Target_Predicted_Aggressive_50_Defence_Target',
       'Target_Predicted_Aggressive_50_Aggresive_T',
       'Target_Predicted_Aggressive_50_Ideal_T']


# Columns to remove
columns_to_remove_4= ['Actual_Agressive_80%_dis',
       'Predicted_Agressive_80%_dis','Target_Predicted_Aggressive_80_Defence_Target',
       'Target_Predicted_Aggressive_80_Aggresive_T',
       'Target_Predicted_Aggressive_80_Ideal_T']


# Columns to remove
columns_to_remove_5= ['Actual_Agressive_100%_dis',
       'Predicted_Agressive_100%_dis','Target_Predicted_Aggressive_100_Defence_Target',
       'Target_Predicted_Aggressive_100_Aggresive_T',
       'Target_Predicted_Aggressive_100_Ideal_T']

# %%
# s = pd.read_csv("Processed_5_Processed_5%_Updated_RF_Agressive_5%_results (1).csv")
# s1 = pd.read_csv("Processed_10_Processed_10%_Updated_RF_Agressive_10%_results (1).csv")
# s2 = pd.read_csv("Processed_20_Processed_20%_Updated_RF_Agressive_20%_results (1).csv")
# s3 = pd.read_csv("Processed_50_Processed_50%_Updated_RF_Agressive_50%_results (1).csv")
# s4 = pd.read_csv("Processed_80_Processed_80%_Updated_RF_Agressive_80%_results (1).csv")
# s5 = pd.read_csv("Processed_100_Processed_100%_Updated_RF_Agressive_100%_results (1).csv")

# %%
# Columns to remove
columns_to_remove = [
    'Open', 'High', 'Low', 'Close', 'SellersLevel4',
    'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
    'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
    'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
    'Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target_Agressive','Profit'
]

# %%
s1.drop(columns=columns_to_remove, inplace=True, errors='ignore')
s2.drop(columns=columns_to_remove, inplace=True, errors='ignore')
s3.drop(columns=columns_to_remove, inplace=True, errors='ignore')
s4.drop(columns=columns_to_remove, inplace=True, errors='ignore')
s5.drop(columns=columns_to_remove, inplace=True, errors='ignore')

# %%
# Columns Remove

# %%
s.drop(columns=columns_to_remove_0, inplace=True, errors='ignore')
s1.drop(columns=columns_to_remove_1, inplace=True, errors='ignore')
s2.drop(columns=columns_to_remove_2, inplace=True, errors='ignore')
s3.drop(columns=columns_to_remove_3, inplace=True, errors='ignore')
s4.drop(columns=columns_to_remove_4, inplace=True, errors='ignore')
s5.drop(columns=columns_to_remove_5, inplace=True, errors='ignore')

# %%
import pandas as pd

# Example DataFrames
# s = pd.read_csv('path_to_s.csv')
# s1 = pd.read_csv('path_to_s1.csv')
# s2 = pd.read_csv('path_to_s2.csv')
# s3 = pd.read_csv('path_to_s3.csv')
# s4 = pd.read_csv('path_to_s4.csv')
# s5 = pd.read_csv('path_to_s5.csv')

# List of DataFrames
dataframes = [s, s1, s2, s3,s4,s5]

# Function to convert 'Time Stamp' to datetime
def convert_to_datetime(df):
    df['Time Stamp'] = pd.to_datetime(df['Time Stamp'])
    return df

# Function to rename columns to ensure uniqueness
def rename_columns(df, suffix):
    return df.rename(columns=lambda x: x if x == 'Time Stamp' else f'{x}_{suffix}')

# Convert 'Time Stamp' to datetime in each DataFrame
dataframes = [convert_to_datetime(df) for df in dataframes]

# Rename columns in each DataFrame to ensure unique names
renamed_dataframes = [rename_columns(df, i) for i, df in enumerate(dataframes)]

# Merge DataFrames on 'Time Stamp'
merged_df = renamed_dataframes[0]

for df in renamed_dataframes[1:]:
    merged_df = pd.merge(merged_df, df, on='Time Stamp', how='inner')

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open_0', 'High_0', 'Low_0', 'Close_0', 'SellersLevel4_0',
#        'SellersLevel3_0', 'SellersLevel2_0', 'SellersLevel1_0',
#        'SellersLevel0_0', 'BuyersLevel0_0', 'BuyersLevel1_0', 'BuyersLevel2_0',
#        'BuyersLevel3_0', 'BuyersLevel4_0', 'BuyersInControlPrice_0',
#        'SellersInControlPrice_0', 'Entry_0', 'Defence_0', 'Stop_0', 'Target_0',
#        'Target_Actual_Agressive_5_dis_0', 'Predicted_Agressive_5_dis_0',
#        'Profit_0', 'Profit_5_Actual_Aggressive_Target_0', 'PAT_Profit_5_0',
#        'PAT_D_Profit_5_0', 'Target_Predicted_Aggressive_5_Loss_0',
#        'Target_Actual_Agressive_10_dis_1', 'Predicted_Agressive_10_dis_1',
#        'Profit_10_Actual_Aggressive_Target_1', 'PAT_Profit_10_1',
#        'PAT_D_Profit_10_1', 'Target_Predicted_Aggressive_10_Loss_1',
#        'Target_Actual_Agressive_20_dis_2', 'Predicted_Agressive_20_dis_2',
#        'Profit_20_Actual_Aggressive_Target_2', 'PAT_Profit_20_2',
# ...

# %%
merged_df.to_csv("C:\\Users\\dell\\Desktop\\Model Analysis\\Merged_data\\Merged_Data_1.csv",index=False)

# %%
s=pd.read_csv("C:\\Users\\dell\\Desktop\\Model Analysis\\Merged_data\\Merged_Data_1.csv")

# %%
# los = pd.read_csv("C:\\Users\\dell\\Desktop\\Model Analysis\\Merged_data\\Merged_Data_1.csv")

# %%
# merged_df["Actual_Profit"] = los["T_Profit"]
#  merged_df["Actual_Loss"] = los["Loss"]

# %%
s.columns
# Out:
# Index(['Time Stamp', 'Open_0', 'High_0', 'Low_0', 'Close_0', 'SellersLevel4_0',
#        'SellersLevel3_0', 'SellersLevel2_0', 'SellersLevel1_0',
#        'SellersLevel0_0', 'BuyersLevel0_0', 'BuyersLevel1_0', 'BuyersLevel2_0',
#        'BuyersLevel3_0', 'BuyersLevel4_0', 'BuyersInControlPrice_0',
#        'SellersInControlPrice_0', 'Entry_0', 'Defence_0', 'Stop_0', 'Target_0',
#        'Target_Actual_Agressive_5_dis_0', 'Predicted_Agressive_5_dis_0',
#        'Profit_0', 'Profit_5_Actual_Aggressive_Target_0', 'PAT_Profit_5_0',
#        'PAT_D_Profit_5_0', 'Target_Predicted_Aggressive_5_Loss_0',
#        'Target_Actual_Agressive_10_dis_1', 'Predicted_Agressive_10_dis_1',
#        'Profit_10_Actual_Aggressive_Target_1', 'PAT_Profit_10_1',
#        'PAT_D_Profit_10_1', 'Target_Predicted_Aggressive_10_Loss_1',
#        'Target_Actual_Agressive_20_dis_2', 'Predicted_Agressive_20_dis_2',
#        'Profit_20_Actual_Aggressive_Target_2', 'PAT_Profit_20_2',
# ...

# %%
s.columns = s.columns.str.replace(r'(_\d+)$', '', regex=True)

# %%
s.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Agressive_5_dis',
#        'Predicted_Agressive_5_dis', 'Profit',
#        'Profit_5_Actual_Aggressive_Target', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
#        'Predicted_Agressive_10_dis', 'Profit_10_Actual_Aggressive_Target',
#        'PAT_Profit_10', 'PAT_D_Profit_10',
#        'Target_Predicted_Aggressive_10_Loss', 'Target_Actual_Agressive_20_dis',
#        'Predicted_Agressive_20_dis', 'Profit_20_Actual_Aggressive_Target',
#        'PAT_Profit_20', 'PAT_D_Profit_20',
#        'Target_Predicted_Aggressive_20_Loss', 'Target_Actual_Agressive_50_dis',
# ...

# %%
import pandas as pd
from tqdm import tqdm
import os

def apply_trading_logic(df):
    # Initialize the new columns with 0
    df['T_Profit'] = 0
    df['D_Profit'] = 0
    df['Loss'] = 0
    df['Ideal_Target_Buyer'] = 0
    df['Defence_Target_Buyer'] = 0
    df['Ideal_Target_Seller'] = 0
    df['Defence_Target_Seller'] = 0

    # Iterate over each row with tqdm for progress tracking
    for i in tqdm(range(len(df))):
        row = df.iloc[i]

        # Entry Value Check
        if row['Entry'] != 0:
            entry = row['Entry']
            defence = row['Defence']

            # Buyers Logic
            if row['BuyersInControlPrice'] != 0:
                # Defence Check
                low_future_rows = df.iloc[i+1:]['Low']
                matched_low_index = low_future_rows[low_future_rows == defence].index
                if not matched_low_index.empty:
                    matched_low_index = matched_low_index[0]
                    max_high = df.loc[i:matched_low_index, 'High'].max()
                    max_close = df.loc[i:matched_low_index, 'Close'].max()

                    df.loc[i, 'Ideal_Target_Buyer'] = max_close
                    # df.loc[i, 'Ideal_Target_Agressive'] = max_high

                    # Target vs. Max High Value Comparison
                    if row['Target'] <= max_high:
                        df.loc[i, 'T_Profit'] = row['Target'] - entry
                    else:
                        stop = row['Stop']
                        if stop != 0:
                            df.loc[i, 'Defence_Target_Buyer'] = ((entry + defence) / 2) + 0.25
                            matched_stop_index = low_future_rows[low_future_rows == stop].index
                            if not matched_stop_index.empty:
                                matched_stop_index = matched_stop_index[0]
                                max_high_stop = df.loc[i:matched_stop_index, 'High'].max()
                                max_close_stop = df.loc[i:matched_stop_index, 'Close'].max()

                                # Defence Target vs. Max High Value Comparison
                                if df.loc[i, 'Defence_Target_Buyer'] <= max_high_stop:
                                    df.loc[i, 'D_Profit'] = df.loc[i, 'Defence_Target_Buyer'] - entry
                                else:
                                    df.loc[i, 'Loss'] = df.loc[i, 'Defence_Target_Buyer'] - entry

            # Sellers Logic
            if row['SellersInControlPrice'] != 0:
                # Defence Check
                high_future_rows = df.iloc[i+1:]['High']
                matched_high_index = high_future_rows[high_future_rows == defence].index
                if not matched_high_index.empty:
                    matched_high_index = matched_high_index[0]
                    min_low = df.loc[i:matched_high_index, 'Low'].min()
                    min_close = df.loc[i:matched_high_index, 'Close'].min()

                    df.loc[i, 'Ideal_Target_Seller'] = min_close
                    # df.loc[i, 'Ideal_Target_Agressive'] = min_low

                    # Target vs. Min Low Value Comparison
                    if row['Target'] >= min_low:
                        df.loc[i, 'T_Profit'] = entry - row['Target']
                    else:
                        stop = row['Stop']
                        if stop != 0:
                            df.loc[i, 'Defence_Target_Seller'] = ((entry + defence) / 2) - 0.25
                            matched_stop_index = high_future_rows[high_future_rows == stop].index
                            if not matched_stop_index.empty:
                                matched_stop_index = matched_stop_index[0]
                                min_low_stop = df.loc[i:matched_stop_index, 'Low'].min()
                                min_close_stop = df.loc[i:matched_stop_index, 'Close'].min()

                                # Defence Target vs. Min Low Value Comparison
                                if df.loc[i, 'Defence_Target_Seller'] >= min_low_stop:
                                    df.loc[i, 'D_Profit'] = entry - df.loc[i, 'Defence_Target_Seller']
                                else:
                                    df.loc[i, 'Loss'] = df.loc[i, 'Defence_Target_Seller'] - entry

        # Additional Calculations
        # df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
        # df.loc[i, 'Defence_Target'] = df.loc[i, 'Defence_Target_Buyer'] + df.loc[i, 'Defence_Target_Seller']

    # Drop unnecessary columns if they exist
    columns_to_drop = ["Ideal_Target_Buyer", "Ideal_Target_Seller", "Defence_Target_Buyer", "Defence_Target_Seller"]
    df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

    return df

# %%
Merged_df_loss= apply_trading_logic(s)
# Out:
#   0%|          | 0/2928 [00:00<?, ?it/s]
# C:\Users\dell\AppData\Local\Temp\ipykernel_15088\3670551770.py:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5639.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target_Seller'] = min_close
# C:\Users\dell\AppData\Local\Temp\ipykernel_15088\3670551770.py:71: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'T_Profit'] = entry - row['Target']
# ...

# %%
Merged_df_loss.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Agressive_5_dis',
#        'Predicted_Agressive_5_dis', 'Profit',
#        'Profit_5_Actual_Aggressive_Target', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
#        'Predicted_Agressive_10_dis', 'Profit_10_Actual_Aggressive_Target',
#        'PAT_Profit_10', 'PAT_D_Profit_10',
#        'Target_Predicted_Aggressive_10_Loss', 'Target_Actual_Agressive_20_dis',
#        'Predicted_Agressive_20_dis', 'Profit_20_Actual_Aggressive_Target',
#        'PAT_Profit_20', 'PAT_D_Profit_20',
#        'Target_Predicted_Aggressive_20_Loss', 'Target_Actual_Agressive_50_dis',
# ...

# %%
Merged_df_loss.drop(columns=['T_Profit','D_Profit'],inplace=True,axis=1)

# %%
Merged_df_loss.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Agressive_5_dis',
#        'Predicted_Agressive_5_dis', 'Profit',
#        'Profit_5_Actual_Aggressive_Target', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
#        'Predicted_Agressive_10_dis', 'Profit_10_Actual_Aggressive_Target',
#        'PAT_Profit_10', 'PAT_D_Profit_10',
#        'Target_Predicted_Aggressive_10_Loss', 'Target_Actual_Agressive_20_dis',
#        'Predicted_Agressive_20_dis', 'Profit_20_Actual_Aggressive_Target',
#        'PAT_Profit_20', 'PAT_D_Profit_20',
#        'Target_Predicted_Aggressive_20_Loss', 'Target_Actual_Agressive_50_dis',
# ...

# %%
Merged_df_loss.rename({'Loss':'Actual_loss','Profit':"Actual_Profit"},inplace=True,axis=1)

# %%
Merged_df_loss.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Agressive_5_dis',
#        'Predicted_Agressive_5_dis', 'Actual_Profit',
#        'Profit_5_Actual_Aggressive_Target', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
#        'Predicted_Agressive_10_dis', 'Profit_10_Actual_Aggressive_Target',
#        'PAT_Profit_10', 'PAT_D_Profit_10',
#        'Target_Predicted_Aggressive_10_Loss', 'Target_Actual_Agressive_20_dis',
#        'Predicted_Agressive_20_dis', 'Profit_20_Actual_Aggressive_Target',
#        'PAT_Profit_20', 'PAT_D_Profit_20',
#        'Target_Predicted_Aggressive_20_Loss', 'Target_Actual_Agressive_50_dis',
# ...

# %%
import pandas as pd

# Function to add prefix "Target_" wherever the column name starts with "Predicted"
def add_prefix_to_predicted_columns(columns):
    return ['Target_' + col if col.startswith('Predicted') else col for col in columns]

# Assuming Merged_df_loss is your dataframe
# Apply the function to the dataframe's column names
updated_columns = add_prefix_to_predicted_columns(Merged_df_loss.columns)

# Update the dataframe with the new column names
Merged_df_loss.columns = updated_columns

# Display the updated column names
print(Merged_df_loss.columns)
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Target_Actual_Agressive_5_dis',
#        'Target_Predicted_Agressive_5_dis', 'Actual_Profit',
#        'Profit_5_Actual_Aggressive_Target', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
#        'Target_Predicted_Agressive_10_dis',
#        'Profit_10_Actual_Aggressive_Target', 'PAT_Profit_10',
#        'PAT_D_Profit_10', 'Target_Predicted_Aggressive_10_Loss',
#        'Target_Actual_Agressive_20_dis', 'Target_Predicted_Agressive_20_dis',
#        'Profit_20_Actual_Aggressive_Target', 'PAT_Profit_20',
#        'PAT_D_Profit_20', 'Target_Predicted_Aggressive_20_Loss',
# ...

# %%
c = ['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
       'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
       'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
       'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
       'Entry', 'Defence', 'Stop', 'Target','Actual_Profit','Actual_loss','Profit_100_Actual_Aggressive_Target','PAT_Profit_100','Target_Actual_Agressive_5_dis',
       'Target_Predicted_Agressive_5_dis',
       'Profit_5_Actual_Aggressive_Target', 'PAT_Profit_5', 'PAT_D_Profit_5',
       'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
       'Target_Predicted_Agressive_10_dis',
       'Profit_10_Actual_Aggressive_Target', 'PAT_Profit_10',
       'PAT_D_Profit_10', 'Target_Predicted_Aggressive_10_Loss',
       'Target_Actual_Agressive_20_dis', 'Target_Predicted_Agressive_20_dis',
       'Profit_20_Actual_Aggressive_Target', 'PAT_Profit_20',
       'PAT_D_Profit_20', 'Target_Predicted_Aggressive_20_Loss',
       'Target_Actual_Agressive_50_dis', 'Target_Predicted_Agressive_50_dis',
       'Profit_50_Actual_Aggressive_Target', 'PAT_Profit_50',
       'PAT_D_Profit_50', 'Target_Predicted_Aggressive_50_Loss',
       'Target_Actual_Agressive_80_dis', 'Target_Predicted_Agressive_80_dis',
       'Profit_80_Actual_Aggressive_Target', 'PAT_Profit_80',
       'PAT_D_Profit_80', 'Target_Predicted_Aggressive_80_Loss',
       'Target_Actual_Agressive_100_dis', 'Target_Predicted_Agressive_100_dis',
       'PAT_D_Profit_100', 'Target_Predicted_Aggressive_100_Loss'
      
       ]

# %%
Merged_df_loss = Merged_df_loss[c]

# %%
Merged_df_loss.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_Profit', 'Actual_loss',
#        'Profit_100_Actual_Aggressive_Target', 'PAT_Profit_100',
#        'Target_Actual_Agressive_5_dis', 'Target_Predicted_Agressive_5_dis',
#        'Profit_5_Actual_Aggressive_Target', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
#        'Target_Predicted_Agressive_10_dis',
#        'Profit_10_Actual_Aggressive_Target', 'PAT_Profit_10',
#        'PAT_D_Profit_10', 'Target_Predicted_Aggressive_10_Loss',
#        'Target_Actual_Agressive_20_dis', 'Target_Predicted_Agressive_20_dis',
# ...

# %%
Merged_df_loss.to_csv("C:\\Users\\dell\\Desktop\\Model Analysis\\Merged_data\\Final_Merged_Agressive.csv",index=False)

# %%
Merged_df_loss.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Actual_Profit', 'Actual_loss',
#        'Actual_loss', 'Profit_100_Actual_Aggressive_Target',
#        'Profit_100_Actual_Aggressive_Target', 'PAT_Profit_100',
#        'PAT_Profit_100', 'Target_Actual_Agressive_5_dis',
#        'Target_Predicted_Agressive_5_dis', 'Profit_5_Actual_Aggressive_Target',
#        'PAT_Profit_5', 'PAT_D_Profit_5', 'Target_Predicted_Aggressive_5_Loss',
#        'Actual_Agressive_10%_dis', 'Target_Actual_Agressive_10_dis',
#        'Target_Actual_Agressive_10_dis', 'Target_Predicted_Agressive_10_dis',
#        'Target_Predicted_Agressive_10_dis',
#        'Profit_10_Actual_Aggressive_Target',
# ...

# %%
# # Columns to remove
# columns_to_remove = [
#     'Actual_5%_dis_0', 'Predicted_5%_dis_0', 'PIT_Defence_Target_5_0', 'PIT_Aggresive_T_5_0',
#     'PIT_Defence_Target_10_1', 'PIT_Aggresive_T_10_1', 'PIT_Ideal_T_10_1', 'PIT_Defence_Target_20_2',
#     'PIT_Aggresive_T_20_2', 'PIT_Ideal_T_20_2', 'PIT_Defence_Target_50_3', 'IT_Defence_Target_80_4',
#     'PIT_Aggresive_T_80_4', 'PIT_Ideal_T_80_4', 'Unnamed: 0_5', 'PIT_Aggresive_T_50_3',
#     'PIT_Ideal_T_50_3', 'Actual_dis_T_IT_5', 'Predicted_dis_T_IT_5', 'PIT_Defence_Target_100_5',
#     'PIT_Aggresive_T_100_5', 'PIT_Ideal_T_100_5', 'Profit_1', 'Profit_2', 'Profit_3', 'Profit_4', 'Profit_5'
# ]

# # Remove columns
# df_cleaned = merged_df.drop(columns=columns_to_remove, errors='ignore')

# %%
# df_cleaned.columns
# Out:
# Index(['Time Stamp', 'Open_0', 'High_0', 'Low_0', 'Close_0', 'SellersLevel4_0',
#        'SellersLevel3_0', 'SellersLevel2_0', 'SellersLevel1_0',
#        'SellersLevel0_0', 'BuyersLevel0_0', 'BuyersLevel1_0', 'BuyersLevel2_0',
#        'BuyersLevel3_0', 'BuyersLevel4_0', 'BuyersInControlPrice_0',
#        'SellersInControlPrice_0', 'Entry_0', 'Defence_0', 'Stop_0', 'Target_0',
#        'Ideal_Target_0', 'Target_Actual_5_dis_0', 'Target_Predicted_5_dis_0',
#        'Profit_0', 'Profit_5_dist_actual_0', 'PIT_Profit_5_0',
#        'PIT_D_Profit_5_0', 'PIT_Loss_5_0', 'PIT_Ideal_T_5_0', 'Ideal_Target_1',
#        'Actual_10%_dis_1', 'Predicted_10%_dis_1', 'Target_Actual_10_dis_1',
#        'Target_Predicted_10_dis_1', 'Profit_10_dist_actual_1',
#        'PIT_Profit_10_1', 'PIT_D_Profit_10_1', 'PIT_Loss_10_1',
#        'Ideal_Target_2', 'Actual_20%_dis_2', 'Predicted_20%_dis_2',
#        'Target_Actual_20_dis_2', 'Target_Predicted_20_dis_2',
# ...

# %%
# df_cleaned.to_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Model_Prediction_Merged_Files/Merged-DataFrames/Complete_Merged_data_ideal_target_1.csv",index=False)

# %%
s1 = pd.read_csv("/home/user/Validataion_Data_J's/Merged_Data_files/Complete_Merge_Aggressive_data_files.csv")

# %%
s1.columns = s1.columns.str.replace(r'(_\d+)$', '', regex=True)

# %%
s1.drop(70558,axis=0,inplace=True)

# %%
s1.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close',
#        'Profit_Aggressive_5_dist_actual', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
#        'Target_Predicted_Agressive_10_dis', 'Profit_Aggressive_10_dist_actual',
#        'PAT_Profit_10', 'PAT_D_Profit_10',
#        'Target_Predicted_Aggressive_10_Loss', 'Target_Actual_Agressive_20_dis',
#        'Target_Predicted_Agressive_20_dis', 'Profit_Aggressive_20_dist_actual',
#        'PAT_Profit_20', 'PAT_D_Profit_20',
#        'Target_Predicted_Aggressive_20_Loss', 'Target_Actual_Agressive_50_dis',
#        'Target_Predicted_Agressive_50_dis', 'Profit_Aggressive_50_dist_actual',
#        'PAT_Profit_50', 'PAT_D_Profit_50',
#        'Target_Predicted_Aggressive_50_Loss', 'Target_Actual_Agressive_80_dis',
#        'Target_Predicted_Agressive_80_dis', 'Profit_Aggressive_80_dist_actual',
#        'PAT_Profit_80', 'PAT_D_Profit_80',
# ...

# %%
c = ['Time Stamp', 'Open', 'High', 'Low', 'Close','Target_Actual_Agressive_100_dis',
       'Profit_Aggressive_5_dist_actual', 'PAT_Profit_5', 'PAT_D_Profit_5',
       'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
       'Target_Predicted_Agressive_10_dis', 'Profit_Aggressive_10_dist_actual',
       'PAT_Profit_10', 'PAT_D_Profit_10',
       'Target_Predicted_Aggressive_10_Loss', 'Target_Actual_Agressive_20_dis',
       'Target_Predicted_Agressive_20_dis', 'Profit_Aggressive_20_dist_actual',
       'PAT_Profit_20', 'PAT_D_Profit_20',
       'Target_Predicted_Aggressive_20_Loss', 'Target_Actual_Agressive_50_dis',
       'Target_Predicted_Agressive_50_dis', 'Profit_Aggressive_50_dist_actual',
       'PAT_Profit_50', 'PAT_D_Profit_50',
       'Target_Predicted_Aggressive_50_Loss', 'Target_Actual_Agressive_80_dis',
       'Target_Predicted_Agressive_80_dis', 'Profit_Aggressive_80_dist_actual',
       'PAT_Profit_80', 'PAT_D_Profit_80',
       'Target_Predicted_Aggressive_80_Loss', 'Actual_Agressive_100%_dis',
       'Target_Actual_Agressive_100_dis', 'Target_Predicted_Agressive_100_dis',
       'Profit_Aggressive_100_dist_actual', 'PAT_Profit_100',
       'PAT_D_Profit_100', 'Target_Predicted_Aggressive_100_Loss']

# %%
s1 = s1[c]

# %%
s1.to_csv("/home/user/Validataion_Data_J's/Merged_Data_files/Complete_Merge_Aggressive_data_files.csv",index=False)

# %% [markdown]
# **FINAL_MERGED_DATA_CALCULATION**

# %%
ideal_t = pd.read_csv("/home/user/Validataion_Data_J's/Merged_Data_files/Complete_Merged_data_Aggressive_target.csv")

# %%
ideal_t = pd.read_csv("/home/user/Validataion_Data_J's/Merged_Data_files/Complete_Merged_data_Ideal_target_1.csv")

# %%
Agg_t = pd.read_csv("/home/user/Validataion_Data_J's/Merged_Data_files/Complete_Merge_Aggressive_data_files.csv")

# %%
ideal_t.columns
# Out:
# Index(['Unnamed: 0', 'Time Stamp', 'Open', 'High', 'Low', 'Close',
#        'BuyersInControlPrice', 'SellersInControlPrice', 'Entry', 'Defence',
#        'Stop', 'Target', 'Profit', 'Actual_Loss', 'Ideal_Target',
#        'Profit_5_dist_actual', 'PIT_Profit_5', 'PIT_D_Profit_5', 'PIT_Loss_5',
#        'Target_Actual_10_dis', 'Target_Predicted_10_dis',
#        'Profit_10_dist_actual', 'PIT_Profit_10', 'PIT_D_Profit_10',
#        'PIT_Loss_10', 'Target_Actual_20_dis', 'Target_Predicted_20_dis',
#        'Profit_20_dist_actual', 'PIT_Profit_20', 'PIT_D_Profit_20',
#        'PIT_Loss_20', 'Target_Actual_50_dis', 'Target_Predicted_50_dis',
#        'Profit_50_dist_actual', 'PIT_Profit_50', 'PIT_D_Profit_50',
#        'PIT_Loss_50', 'Target_Actual_80_dis', 'Target_Predicted_80_dis',
#        'Profit_80_dist_actual', 'PIT_Profit_80', 'PIT_D_Profit_80',
#        'PIT_Loss_80', 'Ideal_Target.1', 'Target_Predicted_100_dis',
# ...

# %%
Agg_t.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close',
#        'Target_Actual_Agressive_100_dis', 'Profit_Aggressive_5_dist_actual',
#        'PAT_Profit_5', 'PAT_D_Profit_5', 'Target_Predicted_Aggressive_5_Loss',
#        'Target_Actual_Agressive_10_dis', 'Target_Predicted_Agressive_10_dis',
#        'Profit_Aggressive_10_dist_actual', 'PAT_Profit_10', 'PAT_D_Profit_10',
#        'Target_Predicted_Aggressive_10_Loss', 'Target_Actual_Agressive_20_dis',
#        'Target_Predicted_Agressive_20_dis', 'Profit_Aggressive_20_dist_actual',
#        'PAT_Profit_20', 'PAT_D_Profit_20',
#        'Target_Predicted_Aggressive_20_Loss', 'Target_Actual_Agressive_50_dis',
#        'Target_Predicted_Agressive_50_dis', 'Profit_Aggressive_50_dist_actual',
#        'PAT_Profit_50', 'PAT_D_Profit_50',
#        'Target_Predicted_Aggressive_50_Loss', 'Target_Actual_Agressive_80_dis',
#        'Target_Predicted_Agressive_80_dis', 'Profit_Aggressive_80_dist_actual',
# ...

# %%
# Columns to remove
columns_to_remove = [
    'PIT_Ideal_T_5_0', 'Ideal_Target_1','Actual_10%_dis_1', 'Predicted_10%_dis_1','Ideal_Target_2', 'Actual_20%_dis_2', 'Predicted_20%_dis_2',
    'Ideal_Target_3', 'Actual_50%_dis_3','Predicted_50%_dis_3', 'Ideal_Target_4', 'Actual_80%_dis_4', 'Predicted_80%_dis_4',
    'Ideal_Target_5']

# Remove columns
ideal_t = ideal_t.drop(columns=columns_to_remove, errors='ignore')

# %%
ideal_t.columns
# Out:
# Index(['Time Stamp', 'Open_0', 'High_0', 'Low_0', 'Close_0', 'SellersLevel4_0',
#        'SellersLevel3_0', 'SellersLevel2_0', 'SellersLevel1_0',
#        'SellersLevel0_0', 'BuyersLevel0_0', 'BuyersLevel1_0', 'BuyersLevel2_0',
#        'BuyersLevel3_0', 'BuyersLevel4_0', 'BuyersInControlPrice_0',
#        'SellersInControlPrice_0', 'Entry_0', 'Defence_0', 'Stop_0', 'Target_0',
#        'Target_Actual_5_dis_0', 'Target_Predicted_5_dis_0', 'Profit_0',
#        'Profit_5_dist_actual_0', 'PIT_Profit_5_0', 'PIT_D_Profit_5_0',
#        'PIT_Loss_5_0', 'Target_Actual_10_dis_1', 'Target_Predicted_10_dis_1',
#        'Profit_1', 'Profit_10_dist_actual_1', 'PIT_Profit_10_1',
#        'PIT_D_Profit_10_1', 'PIT_Loss_10_1', 'Target_Actual_20_dis_2',
#        'Target_Predicted_20_dis_2', 'Profit_2', 'Profit_20_dist_actual_2',
#        'PIT_Profit_20_2', 'PIT_D_Profit_20_2', 'PIT_Loss_20_2',
#        'Target_Actual_80_dis_3', 'Target_Predicted_80_dis_3', 'Profit_3',
# ...

# %%
# Columns to remove
columns_to_remove = [
    'Open', 'High', 'Low', 'Close']

# %%
Agg_t.drop(columns=columns_to_remove, inplace=True, errors='ignore')

# %%
Agg_t.columns
# Out:
# Index(['Time Stamp', 'Target_Actual_Agressive_100_dis',
#        'Profit_Aggressive_5_dist_actual', 'PAT_Profit_5', 'PAT_D_Profit_5',
#        'Target_Predicted_Aggressive_5_Loss', 'Target_Actual_Agressive_10_dis',
#        'Target_Predicted_Agressive_10_dis', 'Profit_Aggressive_10_dist_actual',
#        'PAT_Profit_10', 'PAT_D_Profit_10',
#        'Target_Predicted_Aggressive_10_Loss', 'Target_Actual_Agressive_20_dis',
#        'Target_Predicted_Agressive_20_dis', 'Profit_Aggressive_20_dist_actual',
#        'PAT_Profit_20', 'PAT_D_Profit_20',
#        'Target_Predicted_Aggressive_20_Loss', 'Target_Actual_Agressive_50_dis',
#        'Target_Predicted_Agressive_50_dis', 'Profit_Aggressive_50_dist_actual',
#        'PAT_Profit_50', 'PAT_D_Profit_50',
#        'Target_Predicted_Aggressive_50_Loss', 'Target_Actual_Agressive_80_dis',
#        'Target_Predicted_Agressive_80_dis', 'Profit_Aggressive_80_dist_actual',
#        'PAT_Profit_80', 'PAT_D_Profit_80',
# ...

# %%
#  Convert 'Time Stamp' to datetime if it's not already
ideal_t['Time Stamp'] = pd.to_datetime(ideal_t['Time Stamp'])
Agg_t['Time Stamp'] = pd.to_datetime(Agg_t['Time Stamp'])

# Merge the DataFrames based on 'Time Stamp'
merged_df = pd.merge(ideal_t, Agg_t, on='Time Stamp', how='inner')

# %%
merged_df = merged_df.rename(columns={'Target_Actual_Agressive_100_dis': 'Aggressive_Target'})

# %%
merged_df.to_csv("/home/user/Validataion_Data_J's/final_merged_Data_ideal_aggressive/Final_Complete_Merged_data_ideal_Aggressive_target_1.csv",index=False)

# %%
merged_df.columns
# Out:
# Index(['Time Stamp', 'Open_0', 'High_0', 'Low_0', 'Close_0', 'SellersLevel4_0',
#        'SellersLevel3_0', 'SellersLevel2_0', 'SellersLevel1_0',
#        'SellersLevel0_0',
#        ...
#        'PAT_D_Profit_80_4', 'Target_Predicted_Aggressive_80_Loss_4',
#        'Actual_Agressive_Target_dis_5', 'Predicted_Agressive_Target_dis_5',
#        'Target_Actual_Agressive_100_dis_5',
#        'Target_Predicted_Agressive_100_dis_5',
#        'Profit_Aggressive_100_dist_actual_5', 'PAT_Profit_100_5',
#        'PAT_D_Profit_100_5', 'Target_Predicted_Aggressive_100_Loss_5'],
#       dtype='object', length=113)

# %%
s = pd.read_csv("/home/user/Validataion_Data_J's/Merged_Data_files/Final_Complete_Merged_data_ideal_Aggressive_target_1.csv")

# %%
s['Time Stamp'] = pd.to_datetime(s['Time Stamp'])

# %%
# Columns to remove
columns_to_remove = ["Profit_2","Profit_1","Profit_3","Profit_4"]
s.drop(columns=columns_to_remove, inplace=True, errors='ignore')

# %%
# Apply absolute value only to numeric columns
numeric_cols = s.select_dtypes(include=['int', 'float']).columns
s[numeric_cols] = s[numeric_cols].abs()
# Out:
#                Time Stamp   Open_0   High_0    Low_0  Close_0  \
# 0     2023-06-23 11:35:00  4619.25  4621.00  4617.75  4619.50
# 1     2023-06-23 11:40:00  4619.50  4624.25  4619.00  4623.25
# 2     2023-06-23 11:45:00  4623.25  4627.75  4622.75  4626.25
# 3     2023-06-23 11:50:00  4626.25  4627.75  4624.75  4626.00
# 4     2023-06-23 11:55:00  4626.00  4626.50  4623.75  4625.25
# ...                   ...      ...      ...      ...      ...
# 70553 2024-06-21 16:35:00  5536.75  5537.75  5536.25  5536.75
# 70554 2024-06-21 16:40:00  5536.75  5537.50  5536.50  5536.75
# 70555 2024-06-21 16:45:00  5537.00  5537.50  5536.50  5536.75
# 70556 2024-06-21 16:50:00  5536.75  5537.25  5536.25  5536.50
# 70557 2024-06-21 16:55:00  5536.25  5536.75  5536.00  5536.50
#
#        SellersLevel4_0  SellersLevel3_0  SellersLevel2_0  SellersLevel1_0  \
# 0              4627.25          4626.00          4625.75          4623.50
# ...

# %%
s.to_csv("/home/user/Validataion_Data_J's/Merged_Data_files/Final_Complete_Merged_data_ideal_Aggressive_target_1.csv",index=False)
