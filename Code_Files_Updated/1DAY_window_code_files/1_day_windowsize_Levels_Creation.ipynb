# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import glob
pd.set_option('display.max_columns',40)
pd.set_option('display.max_rows', 300)  # Show all rows

os.chdir('/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24')
# Path to your data folder in Google Drive
data_folder = '/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24'

# List files in the specified folder to confirm access
folder_path = os.path.join(data_folder)  # Update 'path_to_your_data_folder' with your actual folder path
file_list = os.listdir(folder_path)
file_list
# Out:
# ['Code_files',
#  'Updated_data',
#  'merged_data_sorted.csv',
#  'merged_data_sorted(BSE500).csv',
#  'merged_data_sorted(BSE100).csv',
#  'merged_data_sorted(BANKNIFTY).csv',
#  'Model_pkl_files',
#  'merged_data_sorted(TATASTEEL).csv',
#  'merged_data_sorted(WIPRO).csv',
#  'merged_data_sorted(INFY).csv']

# %%
data = pd.read_csv("merged_data_sorted(BANKNIFTY).csv")

# %%
data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
data.rename({'timestamp':'Time Stamp','open':'Open','high':'High','low':'Low','close':'Close'},inplace=True,axis=1)

# %%
data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
data.drop(columns=['volume'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-50f62f12922e> in <cell line: 1>()
# ----> 1 data.drop(columns=['volume'],inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['volume'] not found in axis"

# %%
data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# import pandas as pd

# def calculate_levels(data):
#     # Initialize level storage for 5 levels
#     buyer_levels = [None] * 5  # 5 buyer levels
#     seller_levels = [None] * 5  # 5 seller levels

#     # Initialize the last known levels for replication
#     last_buyer_levels = [0] * 5
#     last_seller_levels = [0] * 5

#     results = []

#     for i in range(len(data) - 2):
#         # Extract 3 consecutive candles
#         candles = data.iloc[i:i + 3]
#         index = candles.index[-1]

#         # Extract Open and Close prices for each candle
#         open_0, close_0 = candles['Open'].iloc[0], candles['Close'].iloc[0]
#         open_1, close_1 = candles['Open'].iloc[1], candles['Close'].iloc[1]
#         open_2, close_2 = candles['Open'].iloc[2], candles['Close'].iloc[2]

#         candidate_buyer_levels = sorted(candles['Low'].unique())
#         candidate_seller_levels = sorted(candles['High'].unique())

#         new_buyer_level = new_seller_level = None

#         # Check if all three candles are increasing (buyer trend)
#         if (close_0 > open_0 and close_1 > open_1 and close_2 > open_2):
#             # Calculate buyer levels
#             for level in candidate_buyer_levels:
#                 if level not in buyer_levels:
#                     new_buyer_level = level
#                     break

#             if new_buyer_level is not None:
#                 if all(buyer_levels) and new_buyer_level > max(buyer_levels):
#                     buyer_levels = buyer_levels[1:] + [new_buyer_level]
#                 else:
#                     buyer_levels = sorted([new_buyer_level] + [lvl for lvl in buyer_levels if lvl is not None])[:5]
#             buyer_levels += [None] * (5 - len(buyer_levels))

#             last_buyer_levels = buyer_levels.copy()  # Update the last known buyer levels

#             # Append buyer levels and carry forward seller levels
#             results.append((index, *buyer_levels, *last_seller_levels))

#         # Check if all three candles are decreasing (seller trend)
#         elif (close_0 < open_0 and close_1 < open_1 and close_2 < open_2):
#             for level in candidate_seller_levels:
#                 if level not in seller_levels:
#                     new_seller_level = level
#                     break

#             if new_seller_level is not None:
#                 if all(seller_levels) and new_seller_level > max(seller_levels):
#                     seller_levels = seller_levels[1:] + [new_seller_level]
#                 else:
#                     seller_levels = sorted([new_seller_level] + [lvl for lvl in seller_levels if lvl is not None])[:5]
#             seller_levels += [None] * (5 - len(seller_levels))

#             last_seller_levels = seller_levels.copy()  # Update the last known seller levels

#             # Append seller levels and carry forward buyer levels
#             results.append((index, *last_buyer_levels, *seller_levels))

#         else:
#             # No trend detected: replicate the last known levels
#             results.append((index, *last_buyer_levels, *last_seller_levels))

#     # Convert the results into a DataFrame with specified column names
#     levels_df = pd.DataFrame(results, columns=[
#         'Index', 'Buyer Level 0', 'Buyer Level 1', 'Buyer Level 2', 'Buyer Level 3', 'Buyer Level 4',
#         'Seller Level 0', 'Seller Level 1', 'Seller Level 2', 'Seller Level 3', 'Seller Level 4'
#     ])

#     # Combine with original data
#     combined_df = pd.concat([data.iloc[2:].reset_index(drop=True), levels_df.reset_index(drop=True)], axis=1)
#     combined_df = combined_df.drop(columns=['Index'])
#     combined_df.fillna(0,inplace=True)
#     return combined_df

# # Example usage
# # data = pd.read_csv('your_data.csv')  # Load your data
# # result_df = calculate_levels(data)
# # print(result_df)

# %%
# combined_df = calculate_levels(data)

# %%
# combined_df.head(50)

# %%
import pandas as pd

def calculate_levels_1(data):
    # Initialize level storage for 5 levels
    buyer_levels = [None] * 5  # 5 buyer levels
    seller_levels = [None] * 5  # 5 seller levels

    # Initialize the last known levels for replication
    last_buyer_levels = [0] * 5
    last_seller_levels = [0] * 5

    results = []

    for i in range(len(data) - 2):
        # Extract 3 consecutive candles
        candles = data.iloc[i:i + 3]
        index = candles.index[-1]

        # Extract Open and Close prices for each candle
        open_0, close_0 = candles['Open'].iloc[0], candles['Close'].iloc[0]
        open_1, close_1 = candles['Open'].iloc[1], candles['Close'].iloc[1]
        open_2, close_2 = candles['Open'].iloc[2], candles['Close'].iloc[2]

        candidate_buyer_levels = sorted(candles['Low'].unique())
        candidate_seller_levels = sorted(candles['High'].unique())

        new_buyer_level = new_seller_level = None

        # Initialize control prices
        BuyerControlPrice = 0
        SellerControlPrice = 0

        # Check if all three candles are increasing (buyer trend)
        if (close_0 > open_0 and close_1 > open_1 and close_2 > open_2):
            # Calculate buyer levels
            for level in candidate_buyer_levels:
                if level not in buyer_levels:
                    new_buyer_level = level
                    break

            if new_buyer_level is not None:
                if all(buyer_levels) and new_buyer_level > max(buyer_levels):
                    buyer_levels = buyer_levels[1:] + [new_buyer_level]
                else:
                    buyer_levels = sorted([new_buyer_level] + [lvl for lvl in buyer_levels if lvl is not None])[:5]
            buyer_levels += [None] * (5 - len(buyer_levels))

            last_buyer_levels = buyer_levels.copy()  # Update the last known buyer levels

            # Append buyer levels and carry forward seller levels
            results.append((index, *buyer_levels, *last_seller_levels))

        # Check if all three candles are decreasing (seller trend)
        elif (close_0 < open_0 and close_1 < open_1 and close_2 < open_2):
            for level in candidate_seller_levels:
                if level not in seller_levels:
                    new_seller_level = level
                    break

            if new_seller_level is not None:
                if all(seller_levels) and new_seller_level > max(seller_levels):
                    seller_levels = seller_levels[1:] + [new_seller_level]
                else:
                    seller_levels = sorted([new_seller_level] + [lvl for lvl in seller_levels if lvl is not None])[:5]
            seller_levels += [None] * (5 - len(seller_levels))

            last_seller_levels = seller_levels.copy()  # Update the last known seller levels

            # Append seller levels and carry forward buyer levels
            results.append((index, *last_buyer_levels, *seller_levels))

        else:
            # No trend detected: replicate the last known levels
            results.append((index, *last_buyer_levels, *last_seller_levels))

        # Calculate the control prices
        if all(lvl is None for lvl in buyer_levels) and all(lvl is None for lvl in seller_levels):
            BuyerControlPrice = 0
            SellerControlPrice = 0
        elif i > 0:
            prev_close = data.iloc[i + 1]['Close']
            curr_close = close_2

            if prev_close > curr_close:
                SellerControlPrice = curr_close
            elif prev_close < curr_close:
                BuyerControlPrice = curr_close

        # Add control prices to the results
        results[-1] += (BuyerControlPrice, SellerControlPrice)

    # Convert the results into a DataFrame with specified column names
    levels_df = pd.DataFrame(results, columns=[
        'Index', 'Buyer Level 0', 'Buyer Level 1', 'Buyer Level 2', 'Buyer Level 3', 'Buyer Level 4',
        'Seller Level 0', 'Seller Level 1', 'Seller Level 2', 'Seller Level 3', 'Seller Level 4',
        'BuyerControlPrice', 'SellerControlPrice'
    ])

    # Combine with original data
    combined_df = pd.concat([data.iloc[2:].reset_index(drop=True), levels_df.reset_index(drop=True)], axis=1)
    combined_df = combined_df.drop(columns=['Index'])
    combined_df.fillna(0, inplace=True)

    return combined_df

# Example usage
# data = pd.read_csv('your_data.csv')  # Load your data
# result_df = calculate_levels(data)
# print(result_df)

# %%
combined_df_1 = calculate_levels_1(data)

# %%
combined_df_1.sample(50)
# Out:
#               Time Stamp      Open      High       Low     Close  \
# 90394   11/17/2023 11:00  43743.65  43754.50  43710.65  43716.40
# 74879    1/13/2023 12:50  42200.60  42232.95  42192.25  42213.95
# 11270     8/8/2019 11:05  27649.05  27649.85  27614.85  27623.75
# 15458     11/6/2019 9:15  30225.20  30225.20  30060.35  30069.85
# 38337    1/22/2021 14:50  31222.45  31267.25  31207.10  31237.40
# 56743    1/21/2022 14:15  37557.60  37572.05  37468.00  37498.75
# 99128    5/10/2024 12:05  47659.10  47703.30  47631.50  47698.60
# 50260    9/17/2021 12:30  37625.65  37636.45  37532.45  37587.60
# 76410    2/13/2023 15:25  41270.10  41281.10  41240.40  41260.85
# 22147    3/13/2020 10:25  22924.90  22942.05  22532.25  22889.20
# 41588    3/30/2021 14:50  33879.05  33940.00  33879.05  33918.70
# 101972     7/5/2024 9:50  52399.00  52399.00  52295.05  52317.25
# 84440     7/24/2023 9:35  46111.45  46127.35  46081.15  46115.60
# 11299     8/8/2019 13:30  27685.50  27770.30  27668.80  27754.55
# 66608     8/3/2022 12:05  37728.85  37759.40  37728.85  37743.65
# 45990    6/25/2021 12:55  35236.05  35253.65  35223.45  35250.75
# 12561     9/5/2019 12:25  26896.20  26925.65  26882.00  26883.95
# 43073    4/30/2021 13:35  33052.35  33125.05  33049.35  33060.05
# 42330    4/15/2021 14:10  32120.20  32122.65  32045.85  32082.20
# 37966    1/15/2021 15:10  32247.35  32264.80  32222.65  32238.00
# 86912      9/8/2023 9:20  44883.25  44896.70  44851.50  44870.95
# 3733     3/12/2019 14:15  28351.60  28355.95  28336.85  28343.25
# 10247    7/19/2019 13:20  29925.35  29933.45  29876.90  29892.65
# 74294     1/3/2023 14:05  43426.60  43436.50  43404.80  43418.35
# 19747    1/28/2020 10:25  30894.20  30896.25  30862.45  30862.45
# 107392  10/18/2024 11:30  51558.30  51602.60  51532.30  51588.35
# 96642    3/19/2024 11:10  46404.80  46433.05  46395.60  46418.20
# 10870    7/31/2019 15:15  28908.55  28910.70  28880.40  28895.50
# 40940    3/17/2021 10:50  34771.50  34792.65  34764.95  34784.05
# 73429   12/19/2022 10:45  43386.45  43415.70  43379.35  43391.20
# 104794   8/29/2024 13:45  51214.85  51238.50  51195.55  51211.50
# 36714   12/23/2020 10:50  29796.95  29847.85  29795.20  29831.30
# 105461   9/11/2024 13:05  51130.65  51146.50  51114.65  51128.15
# 98310    4/24/2024 12:40  48192.45  48199.60  48183.60  48199.10
# 19429    1/21/2020 15:10  30940.30  30950.30  30920.25  30945.25
# 28512     7/20/2020 9:35  22450.90  22479.90  22428.90  22430.65
# 1676     1/31/2019 11:35  27055.70  27070.90  27031.75  27038.15
# 54323    12/8/2021 12:35  37216.40  37222.35  37172.35  37172.75
# 84988     8/2/2023 11:30  45056.05  45067.00  45030.15  45054.40
# 95386    2/22/2024 14:30  46778.60  46780.00  46679.75  46707.80
# 63583     6/8/2022 10:00  34982.45  35003.45  34954.40  34962.40
# 46531     7/6/2021 14:15  35788.25  35798.05  35725.40  35732.55
# 78659    3/28/2023 15:20  39560.15  39632.95  39560.00  39622.55
# 55127   12/23/2021 10:50  35141.05  35191.35  35141.05  35190.40
# 19585     1/24/2020 9:25  30934.65  31000.45  30921.35  31000.20
# 77642     3/9/2023 11:50  41597.10  41613.35  41543.75  41547.55
# 59184    3/11/2022 12:10  34580.75  34641.05  34580.75  34604.25
# 79620    4/20/2023 14:10  42144.65  42165.10  42128.10  42136.15
# 21734     3/4/2020 13:30  28364.05  28368.90  28316.75  28342.85
# 3763     3/13/2019 10:30  28539.65  28545.35  28518.95  28532.30
#
#         Buyer Level 0  Buyer Level 1  Buyer Level 2  Buyer Level 3  \
# 90394        43574.10       43773.80       44180.65       44185.65
# 74879        41936.20       41964.50       41971.15       41974.15
# 11270        27541.65       27589.35       27597.85       27934.95
# 15458        30122.25       30164.60       30192.15       30302.80
# 38337        31168.95       31176.95       31546.25       31596.45
# 56743        37368.00       37371.30       37374.15       37468.40
# 99128        47569.50       47583.90       47601.65       47660.80
# 50260        37479.05       37528.90       37541.35       37605.60
# 76410        41217.60       41260.40       41276.85       41277.35
# 22147        23880.95       24025.00       24258.60       24324.35
# 41588        33643.20       33664.80       33716.55       33836.20
# 101972       52870.95       52984.80       53033.60       53071.75
# 84440        45948.90       45978.25       45979.50       46038.65
# 11299        27570.80       27589.35       27597.85       27603.70
# 66608        37693.80       37816.05       37894.05       37909.25
# 45990        35098.50       35116.80       35167.85       35190.15
# 12561        27035.10       27063.00       27068.95       27083.30
# 43073        32992.70       33097.25       33107.95       33164.65
# 42330        31498.85       31542.75       31614.65       31712.25
# 37966        32050.40       32098.60       32167.15       32170.35
# 86912        44529.55       44648.20       44687.00       44808.30
# 3733         28230.65       28236.05       28247.85       28270.90
# 10247        30052.30       30103.15       30499.30       30502.75
# 74294        43163.20       43227.35       43283.90       43307.65
# 19747        30761.40       30842.05       30926.85       30947.65
# 107392       51216.80       51249.15       51358.50       51388.25
# 96642        46397.85       46407.80       46486.50       46543.35
# 10870        28654.75       28663.10       28698.35       28733.15
# 40940        34661.75       34849.05       34867.70       34882.35
# 73429        43144.80       43207.25       43211.55       43253.00
# 104794       51149.85       51164.80       51194.00       51248.40
# 36714        29525.10       29532.25       29575.45       29635.00
# 105461       51179.75       51194.85       51224.35       51232.95
# 98310        48040.90       48061.50       48069.35       48098.75
# 19429        30882.00       30917.00       30986.80       31024.60
# 28512        21825.95       21866.85       21899.40       21973.60
# 1676         26900.15       26924.70       26949.50       26965.80
# 54323        36700.25       36914.70       37011.80       37119.05
# 84988        45290.70       45487.00       45495.00       45526.75
# 95386        46542.25       46549.30       46552.50       46662.00
# 63583        34855.50       34887.90       34916.30       34930.20
# 46531        35628.80       35637.50       35641.85       35650.10
# 78659        39328.75       39354.65       39354.80       39388.10
# 55127        34824.80       34863.60       34872.80       34987.90
# 19585        30751.60       30829.75       30929.35       30946.45
# 77642        41290.75       41431.45       41462.05       41524.85
# 59184        34328.85       34429.30       34484.30       34501.10
# 79620        42143.90       42176.40       42227.80       42233.95
# 21734        28732.35       28741.55       28792.45       28844.10
# 3763         28378.10       28403.40       28425.35       28495.10
#
#         Buyer Level 4  Seller Level 0  Seller Level 1  Seller Level 2  \
# 90394        44192.75        43714.60        43742.50        43760.55
# 74879        42001.30        41835.95        41879.00        41937.40
# 11270        27935.10        27668.80        27685.15        27692.85
# 15458        30303.50        30193.30        30201.10        30208.90
# 38337        31606.75        31221.30        31359.15        31401.50
# 56743        37493.45        37352.10        37400.55        37460.90
# 99128        47661.05        47680.10        47683.20        47696.20
# 50260        37930.15        37423.60        37433.30        37569.10
# 76410        41291.10        41284.85        41317.65        41326.55
# 22147        24434.45        23833.20        24388.85        24451.20
# 41588        33859.35        33382.20        33424.65        33653.65
# 101972       53122.45        52523.90        52896.70        52913.40
# 84440        46047.45        45706.45        45719.85        46009.70
# 11299        27628.35        27668.80        27685.15        27692.75
# 66608        37918.55        37740.55        37762.95        37767.75
# 45990        35204.90        34613.05        34685.35        34694.20
# 12561        27096.45        27071.70        27072.95        27099.35
# 43073        33174.90        33159.70        33163.85        33193.65
# 42330        31726.65        30769.10        30941.75        31178.90
# 37966        32253.55        32157.55        32160.90        32200.00
# 86912        44827.10        44409.55        44420.10        44469.15
# 3733         28305.20        27764.20        27968.95        27990.30
# 10247        30507.70        29933.45        29963.95        30066.45
# 74294        43321.30        43126.75        43130.80        43178.00
# 19747        31050.75        30842.40        30844.05        30922.00
# 107392       51489.55        51242.05        51248.35        51276.45
# 96642        46565.00        46396.05        46412.45        46437.95
# 10870        28760.40        28682.05        28712.30        28735.90
# 40940        34887.25        34567.60        34637.95        34689.35
# 73429        43300.45        43214.35        43221.80        43222.10
# 104794       51256.55        51154.60        51163.60        51214.75
# 36714        29659.40        29151.15        29224.55        29239.50
# 105461       51249.55        51033.80        51067.45        51115.80
# 98310        48191.70        47884.95        47964.95        47991.50
# 19429        31059.50        30938.30        30943.95        30958.85
# 28512        22251.35        21230.05        21233.00        21607.25
# 1676         26983.70        26739.65        26782.45        26808.70
# 54323        37143.85        35829.70        35877.10        36566.35
# 84988        45538.80        45060.70        45163.90        45176.65
# 95386        46703.25        46568.10        46584.30        46659.85
# 63583        35022.00        34906.00        35003.45        35012.40
# 46531        35669.50        35092.80        35155.05        35611.15
# 78659        39408.45        39387.90        39390.10        39409.80
# 55127        35095.05        34667.10        34720.00        34771.55
# 19585        30994.60        30788.60        30804.55        30816.65
# 77642        41531.00        41250.70        41297.50        41512.00
# 59184        34570.05        33793.90        34338.65        34472.90
# 79620        42235.10        42133.20        42142.05        42201.90
# 21734        28935.30        28475.50        28485.20        28604.35
# 3763         28553.35        28299.35        28325.40        28433.60
#
#         Seller Level 3  Seller Level 4  BuyerControlPrice  SellerControlPrice
# 90394         43795.75        44143.80               0.00            43716.40
# 74879         41980.00        41981.10           42213.95                0.00
# 11270         27695.25        27705.40               0.00            27623.75
# 15458         30225.20        30233.95               0.00            30069.85
# 38337         31413.50        31580.85           31237.40                0.00
# 56743         37554.70        37572.05               0.00            37498.75
# 99128         47696.80        47698.65           47698.60                0.00
# 50260         37656.45        37690.85               0.00            37587.60
# 76410         41327.30        41349.95               0.00            41260.85
# 22147         24456.00        24519.20               0.00            22889.20
# 41588         33715.85        33916.95           33918.70                0.00
# 101972        52975.00        53105.35               0.00            52317.25
# 84440         46056.60        46106.15           46115.60                0.00
# 11299         27692.85        27706.40           27754.55                0.00
# 66608         37782.65        37786.05           37743.65                0.00
# 45990         34879.50        35073.00           35250.75                0.00
# 12561         27106.40        27108.95               0.00            26883.95
# 43073         33235.20        33302.05           33060.05                0.00
# 42330         31217.45        31491.35               0.00            32082.20
# 37966         32257.15        32315.60               0.00            32238.00
# 86912         44473.55        44497.80               0.00            44870.95
# 3733          28299.35        28325.40               0.00            28343.25
# 10247         30073.30        30087.05               0.00            29892.65
# 74294         43275.00        43436.50               0.00            43418.35
# 19747         30928.30        30980.90               0.00            30862.45
# 107392        51289.25        51560.35           51588.35                0.00
# 96642         46530.15        46575.30           46418.20                0.00
# 10870         28739.90        28869.80               0.00            28895.50
# 40940         34757.55        34814.90           34784.05                0.00
# 73429         43229.05        43257.00           43391.20                0.00
# 104794        51235.75        51268.35               0.00            51211.50
# 36714         29269.35        29619.65           29831.30                0.00
# 105461        51144.50        51334.05               0.00            51128.15
# 98310         48072.75        48203.85           48199.10                0.00
# 19429         30966.30        31338.00           30945.25                0.00
# 28512         21625.70        21639.95               0.00            22430.65
# 1676          26854.55        26924.90               0.00            27038.15
# 54323         36660.95        37195.10               0.00            37172.75
# 84988         45506.25        45507.85           45054.40                0.00
# 95386         46688.25        46719.50               0.00            46707.80
# 63583         35014.40        35028.75               0.00            34962.40
# 46531         35643.30        35650.95               0.00            35732.55
# 78659         39415.75        39417.10           39622.55                0.00
# 55127         34879.90        35199.45           35190.40                0.00
# 19585         30970.45        31003.55           31000.20                0.00
# 77642         41536.70        41613.35               0.00            41547.55
# 59184         34550.60        34619.00           34604.25                0.00
# 79620         42227.45        42230.95               0.00            42136.15
# 21734         28614.20        28648.75               0.00            28342.85
# 3763          28442.25        28550.30               0.00            28532.30

# %%
combined_df_1.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'Buyer Level 0',
#        'Buyer Level 1', 'Buyer Level 2', 'Buyer Level 3', 'Buyer Level 4',
#        'Seller Level 0', 'Seller Level 1', 'Seller Level 2', 'Seller Level 3',
#        'Seller Level 4', 'BuyerControlPrice', 'SellerControlPrice'],
#       dtype='object')

# %%
import pandas as pd

# Assuming 'levels_df' is your DataFrame containing the original columns
# Define the new column names in the desired order, including the first five as they are
new_columns = {
    'Seller Level 4': 'SellersLevel4',
    'Seller Level 3': 'SellersLevel3',
    'Seller Level 2': 'SellersLevel2',
    'Seller Level 1': 'SellersLevel1',
    'Seller Level 0': 'SellersLevel0',
    'Buyer Level 0': 'BuyersLevel0',
    'Buyer Level 1': 'BuyersLevel1',
    'Buyer Level 2': 'BuyersLevel2',
    'Buyer Level 3': 'BuyersLevel3',
    'Buyer Level 4': 'BuyersLevel4',
    'BuyerControlPrice': 'BuyersInControlPrice',
    'SellerControlPrice': 'SellersInControlPrice'
}

# Rearrange and rename columns
combined_df_1 = combined_df_1.rename(columns=new_columns)

# Define the final column order, keeping the first five as they are
final_column_order = [
    'Time Stamp',
    'Open',
    'High',
    'Low',
    'Close',
    'SellersLevel4',
    'SellersLevel3',
    'SellersLevel2',
    'SellersLevel1',
    'SellersLevel0',
    'BuyersLevel0',
    'BuyersLevel1',
    'BuyersLevel2',
    'BuyersLevel3',
    'BuyersLevel4',
    'BuyersInControlPrice',
    'SellersInControlPrice'
]

# Reorder the DataFrame columns
combined_df_1 = combined_df_1[final_column_order]

# %%
combined_df_1.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice'],
#       dtype='object')

# %%
combined_df_1.to_csv('/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/BANKNIFTY/Final_Updated_logic_BANKNIFTY_19NOV.csv',index=False)
