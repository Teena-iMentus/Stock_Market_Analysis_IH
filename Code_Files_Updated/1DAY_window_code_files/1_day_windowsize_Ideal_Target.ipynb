# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
pd.set_option('display.max_columns',40)
from google.colab import drive
import os
os.chdir('/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/BANKNIFTY')

# %%
# Path to your data folder in Google Drive
data_folder = '/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/BANKNIFTY'
# List files in the specified folder to confirm access
folder_path = os.path.join(data_folder)  # Update 'path_to_your_data_folder' with your actual folder path
file_list = os.listdir(folder_path)
file_list
# Out:
# ['Final_Updated_logic_BANKNIFTY_19NOV.csv',
#  'Final_Updated_logic_BANKNIFTY_ESDT_19NOV24.csv',
#  'Experiment_Updated(ESDT)_logic_Indian_stocks_BANKNIFTY_ESDT_19NOV2024.csv']

# %%
s = pd.read_csv("Experiment_Updated(ESDT)_logic_Indian_stocks_BANKNIFTY_ESDT_19NOV2024.csv")

# %%
s.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry_Type', 'Entry', 'Defence', 'Stop', 'Target', 'Defence_Time',
#        'Defence_Time_Value'],
#       dtype='object')

# %%
s.dtypes
# Out:
# Time Stamp                object
# Open                     float64
# High                     float64
# Low                      float64
# Close                    float64
# SellersLevel4            float64
# SellersLevel3            float64
# SellersLevel2            float64
# SellersLevel1            float64
# SellersLevel0            float64
# BuyersLevel0             float64
# BuyersLevel1             float64
# BuyersLevel2             float64
# BuyersLevel3             float64
# BuyersLevel4             float64
# BuyersInControlPrice     float64
# SellersInControlPrice    float64
# Entry_Type                 int64
# Entry                    float64
# Defence                  float64
# Stop                     float64
# Target                   float64
# Defence_Time              object
# Defence_Time_Value       float64
# dtype: object

# %%
# import pandas as pd
# from tqdm import tqdm
# import os

# def apply_trading_logic(df):
#     # Initialize the new columns with 0
#     df['Actual_Profit'] = 0
#     df['D_Profit'] = 0
#     df['Actual_Loss'] = 0
#     df['Ideal_Target_Buyer'] = 0
#     df['Defence_Target_Buyer'] = 0
#     df['Ideal_Target_Seller'] = 0
#     df['Defence_Target_Seller'] = 0
#     df['Defence_Target'] = 0
#     df['Ideal_Target'] = 0
#     df['Ideal_Target_Agressive'] = 0

#     # Iterate over each row with tqdm for progress tracking
#     for i in tqdm(range(len(df))):
#         row = df.iloc[i]

#         # Entry Value Check
#         if row['Entry'] != 0:
#             entry = row['Entry']
#             defence = row['Defence']

#             # Buyers Logic
#             if row['BuyersInControlPrice'] != 0:
#                 # Defence Check
#                 low_future_rows = df.iloc[i+1:]['Low']
#                 matched_low_index = low_future_rows[low_future_rows == defence].index
#                 if not matched_low_index.empty:
#                     matched_low_index = matched_low_index[0]
#                     max_high = df.loc[i:matched_low_index, 'High'].max()
#                     max_close = df.loc[i:matched_low_index, 'Close'].max()

#                     df.loc[i, 'Ideal_Target_Buyer'] = max_close
#                     df.loc[i, 'Ideal_Target_Agressive'] = max_high

#                     # Target vs. Max High Value Comparison
#                     if row['Target'] <= max_high:
#                         df.loc[i, 'Actual_Profit'] = row['Target'] - entry
#                     else:
#                         stop = row['Stop']
#                         if stop != 0:
#                             df.loc[i, 'Defence_Target_Buyer'] = ((entry + defence) / 2) + 0.25
#                             matched_stop_index = low_future_rows[low_future_rows == stop].index
#                             if not matched_stop_index.empty:
#                                 matched_stop_index = matched_stop_index[0]
#                                 max_high_stop = df.loc[i:matched_stop_index, 'High'].max()
#                                 max_close_stop = df.loc[i:matched_stop_index, 'Close'].max()

#                                 # Defence Target vs. Max High Value Comparison
#                                 if df.loc[i, 'Defence_Target_Buyer'] <= max_high_stop:
#                                     df.loc[i, 'D_Profit'] = df.loc[i, 'Defence_Target_Buyer'] - entry
#                                 else:
#                                     df.loc[i, 'Actual_Loss'] = df.loc[i, 'Defence_Target_Buyer'] - entry

#             # Sellers Logic
#             if row['SellersInControlPrice'] != 0:
#                 # Defence Check
#                 high_future_rows = df.iloc[i+1:]['High']
#                 matched_high_index = high_future_rows[high_future_rows == defence].index
#                 if not matched_high_index.empty:
#                     matched_high_index = matched_high_index[0]
#                     min_low = df.loc[i:matched_high_index, 'Low'].min()
#                     min_close = df.loc[i:matched_high_index, 'Close'].min()

#                     df.loc[i, 'Ideal_Target_Seller'] = min_close
#                     df.loc[i, 'Ideal_Target_Agressive'] = min_low

#                     # Target vs. Min Low Value Comparison
#                     if row['Target'] >= min_low:
#                         df.loc[i, 'Actual_Profit'] = entry - row['Target']
#                     else:
#                         stop = row['Stop']
#                         if stop != 0:
#                             df.loc[i, 'Defence_Target_Seller'] = ((entry + defence) / 2) - 0.25
#                             matched_stop_index = high_future_rows[high_future_rows == stop].index
#                             if not matched_stop_index.empty:
#                                 matched_stop_index = matched_stop_index[0]
#                                 min_low_stop = df.loc[i:matched_stop_index, 'Low'].min()
#                                 min_close_stop = df.loc[i:matched_stop_index, 'Close'].min()

#                                 # Defence Target vs. Min Low Value Comparison
#                                 if df.loc[i, 'Defence_Target_Seller'] >= min_low_stop:
#                                     df.loc[i, 'D_Profit'] = entry - df.loc[i, 'Defence_Target_Seller']
#                                 else:
#                                     df.loc[i, 'Actual_Loss'] = df.loc[i, 'Defence_Target_Seller'] - entry

#         # Additional Calculations
#         df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
#         df.loc[i, 'Defence_Target'] = df.loc[i, 'Defence_Target_Buyer'] + df.loc[i, 'Defence_Target_Seller']

#     # Drop unnecessary columns if they exist
#     columns_to_drop = ["Ideal_Target_Buyer", "Ideal_Target_Seller", "Defence_Target_Buyer", "Defence_Target_Seller"]
#     df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

#     return df

# # def process_files(input_directory, output_directory):
# #     # Ensure the output directory exists
# #     os.makedirs(output_directory, exist_ok=True)

# #     # Process each CSV file in the input directory
# #     for filename in os.listdir(input_directory):
# #         if filename.endswith('.csv'):
# #             input_path = os.path.join(input_directory, filename)
# #             # Add prefix "Complete_" to the output file name
# #             output_path = os.path.join(output_directory, f"Complete_{filename}")

# #             # Read the input file
# #             df = pd.read_csv(input_path)

# #             # Convert 'Time Stamp' to datetime
# #             if 'Time Stamp' in df.columns:
# #                 df['Time Stamp'] = pd.to_datetime(df['Time Stamp'], errors='coerce')

# #             # Drop the "Unnamed: 0" column if it exists
# #             if 'Unnamed: 0' in df.columns:
# #                 df.drop(columns=['Unnamed: 0'], inplace=True)

# #             # Apply the trading logic
# #             df = apply_trading_logic(df)

# #             # Save the processed file to the output directory
# #             df.to_csv(output_path, index=False)
# #             print(f"Processed {filename} and saved to {output_path}")


# # # Example usage
# # output_directory = '/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Calculated_Data_Folders/Complete_Data_Files_ideal_Aggressive_with_duplicates'
# # process_files(data_folder, output_directory)

# %%
import pandas as pd
from tqdm import tqdm

def apply_trading_logic(df):
    # Ensure 'Time Stamp' is in datetime format
    df['Time Stamp'] = pd.to_datetime(df['Time Stamp'], errors='coerce')

    # Initialize the new columns with 0
    df['Actual_Profit'] = 0
    df['D_Profit'] = 0
    df['Actual_Loss'] = 0
    df['Ideal_Target_Buyer'] = 0
    df['Defence_Target_Buyer'] = 0
    df['Ideal_Target_Seller'] = 0
    df['Defence_Target_Seller'] = 0
    df['Defence_Target'] = 0
    df['Ideal_Target'] = 0
    df['Ideal_Target_Agressive'] = 0

    # Time to filter until 15:10 (3:10 PM)
    target_time = pd.to_datetime("15:10:00").time()

    # Iterate over each row with tqdm for progress tracking
    for i in tqdm(range(len(df))):
        row = df.iloc[i]

        # Entry Value Check
        if row['Entry'] != 0:
            entry = row['Entry']
            defence = row['Defence']

            # Check if BuyersInControlPrice is not zero
            if row['BuyersInControlPrice'] != 0:
                # Compare the 'Defence' value with future 'Low' values
                low_future_rows = df.iloc[i+1:]['Low']
                matched_low_index = low_future_rows[low_future_rows == defence].index
                if not matched_low_index.empty:
                    matched_low_index = matched_low_index[0]
                    max_close = df.loc[i:matched_low_index, 'Close'].max()
                    df.loc[i, 'Ideal_Target_Buyer'] = max_close
                    df.loc[i, 'Ideal_Target_Agressive'] = df.loc[i:matched_low_index, 'High'].max()
                else:
                    # If no match, calculate the max close till 15:10 for the same date
                    same_day_rows = df.iloc[i+1:].loc[
                        (df['Time Stamp'].dt.date == row['Time Stamp'].date()) &
                        (df['Time Stamp'].dt.time <= target_time)
                    ]
                    if not same_day_rows.empty:
                        max_close_1510 = same_day_rows['Close'].max()
                        df.loc[i, 'Ideal_Target_Buyer'] = max_close_1510

            # Check if SellersInControlPrice is not zero
            if row['SellersInControlPrice'] != 0:
                # Compare the 'Defence' value with future 'High' values
                high_future_rows = df.iloc[i+1:]['High']
                matched_high_index = high_future_rows[high_future_rows == defence].index
                if not matched_high_index.empty:
                    matched_high_index = matched_high_index[0]
                    min_close = df.loc[i:matched_high_index, 'Close'].min()
                    df.loc[i, 'Ideal_Target_Seller'] = min_close
                    df.loc[i, 'Ideal_Target_Agressive'] = df.loc[i:matched_high_index, 'Low'].min()
                else:
                    # If no match, calculate the min close till 15:10 for the same date
                    same_day_rows = df.iloc[i+1:].loc[
                        (df['Time Stamp'].dt.date == row['Time Stamp'].date()) &
                        (df['Time Stamp'].dt.time <= target_time)
                    ]
                    if not same_day_rows.empty:
                        min_close_1510 = same_day_rows['Close'].min()
                        df.loc[i, 'Ideal_Target_Seller'] = min_close_1510

        # Additional Calculations for profit
        df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
        df.loc[i, 'Defence_Target'] = df.loc[i, 'Defence_Target_Buyer'] + df.loc[i, 'Defence_Target_Seller']

    # Drop unnecessary columns if they exist
    columns_to_drop = ["Ideal_Target_Buyer", "Ideal_Target_Seller", "Defence_Target_Buyer", "Defence_Target_Seller"]
    df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

    return df

# %%
# import pandas as pd
# from tqdm import tqdm
# from datetime import timedelta

# def apply_trading_logic(df):
#     # Ensure 'Time Stamp' is in datetime format
#     df['Time Stamp'] = pd.to_datetime(df['Time Stamp'], errors='coerce')

#     # Initialize the new columns with 0
#     df['Actual_Profit'] = 0
#     df['D_Profit'] = 0
#     df['Actual_Loss'] = 0
#     df['Ideal_Target_Buyer'] = 0
#     df['Defence_Target_Buyer'] = 0
#     df['Ideal_Target_Seller'] = 0
#     df['Defence_Target_Seller'] = 0
#     df['Defence_Target'] = 0
#     df['Ideal_Target'] = 0
#     df['Ideal_Target_Agressive'] = 0

#     # Limit the DataFrame to 10,000 rows
#     df = df.iloc[:10000]

#     # Iterate over each row with tqdm for progress tracking
#     for i in tqdm(range(len(df))):
#         row = df.iloc[i]

#         # Entry Value Check
#         if row['Entry'] != 0:
#             entry = row['Entry']
#             defence = row['Defence']

#             # Calculate the end of the 7-day window from the current row's timestamp
#             start_date = row['Time Stamp']
#             end_date = start_date + timedelta(days=7)

#             # Filter future rows within the 7-day window
#             future_rows = df.iloc[i+1:].loc[
#                 (df['Time Stamp'] > start_date) & (df['Time Stamp'] <= end_date)
#             ]

#             # Handle the Buyer control price logic
#             if row['BuyersInControlPrice'] != 0:
#                 if not future_rows.empty:
#                     # Calculate max close and high within the 7-day window
#                     max_close = future_rows['Close'].max()
#                     max_high = future_rows['High'].max()
#                 else:
#                     # If no future rows in the window, take the last available row
#                     max_close = df.iloc[i:]['Close'].max()
#                     max_high = df.iloc[i:]['High'].max()

#                 # Update target columns
#                 df.loc[i, 'Ideal_Target_Buyer'] = max_close
#                 df.loc[i, 'Ideal_Target_Agressive'] = max_high

#             # Handle the Seller control price logic
#             if row['SellersInControlPrice'] != 0:
#                 if not future_rows.empty:
#                     # Calculate min close and low within the 7-day window
#                     min_close = future_rows['Close'].min()
#                     min_low = future_rows['Low'].min()
#                 else:
#                     # If no future rows in the window, take the last available row
#                     min_close = df.iloc[i:]['Close'].min()
#                     min_low = df.iloc[i:]['Low'].min()

#                 # Update target columns
#                 df.loc[i, 'Ideal_Target_Seller'] = min_close
#                 df.loc[i, 'Ideal_Target_Agressive'] = min_low

#         # Additional Calculations for profit
#         df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
#         df.loc[i, 'Defence_Target'] = df.loc[i, 'Defence_Target_Buyer'] + df.loc[i, 'Defence_Target_Seller']

#     # Drop unnecessary columns if they exist
#     columns_to_drop = ["Ideal_Target_Buyer", "Ideal_Target_Seller", "Defence_Target_Buyer", "Defence_Target_Seller"]
#     df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

#     return df

# # Example usage:
# # df = pd.read_csv('your_file.csv') # Load your DataFrame
# # df = apply_trading_logic(df)
# # df.head() # Display the first few rows of the processed DataFrame

# %%
# import pandas as pd
# from tqdm import tqdm

# def apply_trading_logic(df):
#     # Ensure 'Time Stamp' is in datetime format
#     df['Time Stamp'] = pd.to_datetime(df['Time Stamp'], errors='coerce')

#     # Initialize the new columns with 0
#     df['Actual_Profit'] = 0
#     df['D_Profit'] = 0
#     df['Actual_Loss'] = 0
#     df['Ideal_Target_Buyer'] = 0
#     df['Ideal_Target_Seller'] = 0
#     df['Defence_Target'] = 0
#     df['Ideal_Target'] = 0
#     df['Ideal_Target_Agressive'] = 0

#     # Define a 7-day window
#     days_window = pd.Timedelta(days=7)

#     # Iterate over each row using tqdm for progress tracking
#     for i in tqdm(range(len(df))):
#         row = df.iloc[i]

#         # Entry Value Check
#         if row['Entry'] != 0:
#             entry = row['Entry']
#             defence = row['Defence']
#             current_timestamp = row['Time Stamp']

#             # Buyer's Case
#             if row['BuyersInControlPrice'] != 0:
#                 # Check if 'Defence' matches any future 'Low' values within the DataFrame
#                 low_future_rows = df.iloc[i + 1:]
#                 matched_low_index = low_future_rows[low_future_rows['Low'] == defence].index

#                 if not matched_low_index.empty:
#                     # If a match is found, get the maximum close from current to matched row
#                     matched_index = matched_low_index[0]
#                     max_close = df.loc[i:matched_index, 'Close'].max()
#                     df.loc[i, 'Ideal_Target_Buyer'] = max_close
#                 else:
#                     # If no match, look within the next 7 days window
#                     future_window_rows = df.iloc[i + 1:].loc[
#                         (df['Time Stamp'] > current_timestamp) &
#                         (df['Time Stamp'] <= current_timestamp + days_window)
#                     ]

#                     # Check if future window is empty
#                     if not future_window_rows.empty:
#                         max_close_7days = future_window_rows['Close'].max()
#                     else:
#                         # If no future rows, take the last available row's close value
#                         max_close_7days = df.iloc[-1]['Close']

#                     df.loc[i, 'Ideal_Target_Buyer'] = max_close_7days

#             # Seller's Case
#             if row['SellersInControlPrice'] != 0:
#                 # Check if 'Defence' matches any future 'High' values within the DataFrame
#                 high_future_rows = df.iloc[i + 1:]
#                 matched_high_index = high_future_rows[high_future_rows['High'] == defence].index

#                 if not matched_high_index.empty:
#                     # If a match is found, get the minimum close from current to matched row
#                     matched_index = matched_high_index[0]
#                     min_close = df.loc[i:matched_index, 'Close'].min()
#                     df.loc[i, 'Ideal_Target_Seller'] = min_close
#                 else:
#                     # If no match, look within the next 7 days window
#                     future_window_rows = df.iloc[i + 1:].loc[
#                         (df['Time Stamp'] > current_timestamp) &
#                         (df['Time Stamp'] <= current_timestamp + days_window)
#                     ]

#                     # Check if future window is empty
#                     if not future_window_rows.empty:
#                         min_close_7days = future_window_rows['Close'].min()
#                     else:
#                         # If no future rows, take the last available row's close value
#                         min_close_7days = df.iloc[-1]['Close']

#                     df.loc[i, 'Ideal_Target_Seller'] = min_close_7days

#         # Calculate overall Ideal Target and Defence Target
#         df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
#         df.loc[i, 'Defence_Target'] = df.loc[i, 'Ideal_Target_Buyer'] - df.loc[i, 'Ideal_Target_Seller']

#     # Drop unnecessary columns if they exist
#     columns_to_drop = ["Ideal_Target_Buyer", "Ideal_Target_Seller"]
#     df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

#     return df

# %%
final_T_AT = apply_trading_logic(s)
# Out:
#   0%|          | 0/108267 [00:00<?, ?it/s]<ipython-input-8-93204fe57b1d>:70: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27043.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target_Seller'] = min_close_1510
# <ipython-input-8-93204fe57b1d>:73: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27043.2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
#   0%|          | 23/108267 [00:00<26:53, 67.08it/s] <ipython-input-8-93204fe57b1d>:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27386.8' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target_Buyer'] = max_close_1510
#   0%|          | 35/108267 [00:00<21:38, 83.34it/s]<ipython-input-8-93204fe57b1d>:61: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26443.7' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target_Agressive'] = df.loc[i:matched_high_index, 'Low'].min()
# 100%|██████████| 108267/108267 [55:11<00:00, 32.69it/s]

# %%
final_T_AT.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry_Type', 'Entry', 'Defence', 'Stop', 'Target', 'Defence_Time',
#        'Defence_Time_Value', 'Actual_Profit', 'D_Profit', 'Actual_Loss',
#        'Defence_Target', 'Ideal_Target', 'Ideal_Target_Agressive'],
#       dtype='object')

# %%
# final_T_AT[['Dist_Bt_T_IT', 'Dist_Bt_T_IAT']].sample(50)

# %%
final_T_AT.drop(columns=['Actual_Profit','D_Profit', 'Actual_Loss', 'Defence_Target'],axis=1,inplace=True)

# %%
import numpy as np

# Given values
values = [4627.75, 4632.75, 4627.25, 4632]

# Calculate the median
median_value = np.median(values)
median_value
# Out:
# 4629.875

# %%
final_T_AT['Dist_Bt_T_IT'] = (final_T_AT['Ideal_Target'] - final_T_AT['Target'])
final_T_AT['Dist_Bt_T_IAT'] = (final_T_AT['Ideal_Target_Agressive'] - final_T_AT['Target'])

# %%
final_T_AT.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry_Type', 'Entry', 'Defence', 'Stop', 'Target', 'Defence_Time',
#        'Defence_Time_Value', 'Ideal_Target', 'Ideal_Target_Agressive',
#        'Dist_Bt_T_IT', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
final_T_AT[['Dist_Bt_T_IT', 'Dist_Bt_T_IAT']].sample(50)
# Out:
#         Dist_Bt_T_IT  Dist_Bt_T_IAT
# 55107           0.00           0.00
# 71681           0.00           0.00
# 99270           0.00           0.00
# 41811         -39.55      -32704.30
# 41756           0.00           0.00
# 47474           0.00           0.00
# 99584           0.00           0.00
# 42669           0.00           0.00
# 9163            0.00           0.00
# 49776           0.00           0.00
# 73616           0.00           0.00
# 15251           0.00           0.00
# 14086           0.00           0.00
# 85396        -938.65       -1019.45
# 78224           0.00           0.00
# 55512           0.00           0.00
# 59912           0.00           0.00
# 23184           0.00           0.00
# 92458          -1.60      -48462.25
# 58392           0.00           0.00
# 69264        -164.10      -38699.85
# 45005           0.00           0.00
# 103794          0.00           0.00
# 25189           3.25      -18763.20
# 20170           0.00           0.00
# 20594           0.00           0.00
# 44883           0.00           0.00
# 90811           0.00           0.00
# 72031          27.75      -42434.10
# 73864         -90.15      -42510.10
# 95959       -1414.15       -1460.30
# 58063         295.35         324.75
# 54821           0.00           0.00
# 57640           0.00           0.00
# 29787         195.75         212.30
# 90092          26.70      -43638.25
# 42268           0.00           0.00
# 71953           0.00           0.00
# 20074           0.00           0.00
# 78844           0.00           0.00
# 97915           7.20      -47394.85
# 44571          57.70      -35306.60
# 99008          13.45      -47959.15
# 104737          0.00           0.00
# 72689           0.00           0.00
# 53623           0.00           0.00
# 62547        -591.20      -34093.60
# 94480           0.00           0.00
# 41615           0.00           0.00
# 105050          0.00           0.00

# %%
final_T_AT.drop(columns=['Entry_Type'],axis=1,inplace=True)

# %%
final_T_AT.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Defence_Time',
#        'Defence_Time_Value', 'Ideal_Target', 'Ideal_Target_Agressive',
#        'Dist_Bt_T_IT', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
final_T_AT.to_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/BANKNIFTY/Final(1)_1day_windowsize_Updated_Experiment_T_IT_BANKNIFTY_19NOV24.csv",index=False)

# %%
import pandas as pd

# %%
final_data = pd.read_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/New_Final_T_IAT_Indian_stocks_BANKNIFTY_6nov24.csv")

# %%
final_data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target',
#        'Ideal_Target_Agressive', 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
final_data.shape
# Out:
# (108267, 25)

# %%
final_data_count = final_data[(final_data['Entry'] != 0) & (final_data['Defence'] !=0) & (final_data['Stop'] !=0) &  (final_data['Target'] !=0) &  (final_data['Ideal_Target'] !=0)].shape[0]

# %%
final_data_count
# Out:
# 3086

# %%
final_data_count_A = final_data[(final_data['BuyersInControlPrice'] != 0) & (final_data['Entry'] != 0) & (final_data['Defence'] !=0) & (final_data['Stop'] !=0) &  (final_data['Target'] !=0) &  (final_data['Ideal_Target'] !=0)].shape[0]

# %%
final_data_count_A
# Out:
# 1601

# %%
final_data_count_B = final_data[(final_data['SellersInControlPrice'] != 0) & (final_data['Entry'] != 0) & (final_data['Defence'] !=0) & (final_data['Stop'] !=0) &  (final_data['Target'] !=0) &  (final_data['Ideal_Target'] !=0)].shape[0]

# %%
final_data_count_B
# Out:
# 1485

# %%
final_T_AT.loc[final_T_AT['Ideal_Target'] == 0, 'Ideal_Target'] = final_T_AT['Target']
final_T_AT.loc[final_T_AT['Ideal_Target_Agressive'] == 0, 'Ideal_Target_Agressive'] = final_T_AT['Ideal_Target']

# %%
# Filter the DataFrame to show only rows where 'Target' != 0
final_T_AT[(final_T_AT['Target'] != 0) & (final_T_AT['Ideal_Target'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Time Stamp, Open, High, Low, Close, SellersLevel4, SellersLevel3, SellersLevel2, SellersLevel1, SellersLevel0, BuyersLevel0, BuyersLevel1, BuyersLevel2, BuyersLevel3, BuyersLevel4, BuyersInControlPrice, SellersInControlPrice, Entry_Type, Entry, Defence, Stop, Target, Ideal_Target, Ideal_Target_Agressive, Dist_Bt_T_IT, Dist_Bt_T_IAT]
# Index: []

# %%
final_T_AT.drop(["Entry_Type"],axis=1,inplace=True)

# %%
final_T_AT.to_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/Finnhub_23oct24/Updated_data/Processed_Complet_IAT_Updated_Data_Finnhub_23oct24.csv",index=False)

# %%
_it[(s_it['Target'] != 0) & (s_it['Ideal_Target'] == 0)]

# %%
s_it.loc[s_it['Ideal_Target'] == 0, 'Ideal_Target'] = s_it['Target']

# %%
s_it.loc[s_it['Ideal_Target_Agressive'] == 0, 'Ideal_Target_Agressive'] = s_it['Ideal_Target']

# %%
final_T_AT.to_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Calculated_Data_Folders/Complete_Data_Files_ideal_Aggressive_without_duplicates/Processed_ESDT_ZB 09-24_Minute_5.csv",index=False)

# %%
complete_T_IT = apply_trading_logic(s)
# Out:
#   0%|          | 0/70558 [00:00<?, ?it/s]<ipython-input-14-ae8a1401be9a>:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4580.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target_Agressive'] = min_low
# <ipython-input-14-ae8a1401be9a>:76: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '3.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'T_Profit'] = entry - row['Target']
# <ipython-input-14-ae8a1401be9a>:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35.25' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Dist_Bt_T_It'] = abs(df.loc[i, 'Ideal_Target'] - row['Target'])
# <ipython-input-14-ae8a1401be9a>:97: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '38.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Dist_Bt_T_IAT'] = abs(df.loc[i, 'Ideal_Target_Agressive'] - row['Target'])
# <ipython-input-14-ae8a1401be9a>:71: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4615.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target_Seller'] = min_close
# <ipython-input-14-ae8a1401be9a>:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4615.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
#   0%|          | 106/70558 [00:00<01:06, 1053.68it/s]<ipython-input-14-ae8a1401be9a>:39: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4632.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Ideal_Target_Buyer'] = max_close
# <ipython-input-14-ae8a1401be9a>:80: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4612.875' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Defence_Target_Seller'] = ((entry + defence) / 2) - 0.25
# <ipython-input-14-ae8a1401be9a>:89: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'D_Profit'] = entry - df.loc[i, 'Defence_Target_Seller']
# <ipython-input-14-ae8a1401be9a>:95: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4612.875' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Defence_Target'] = df.loc[i, 'Defence_Target_Buyer'] + df.loc[i, 'Defence_Target_Seller']
# <ipython-input-14-ae8a1401be9a>:91: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Loss'] = df.loc[i, 'Defence_Target_Seller'] - entry
#   1%|          | 797/70558 [00:00<01:04, 1088.87it/s]<ipython-input-14-ae8a1401be9a>:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4653.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Defence_Target_Buyer'] = ((entry + defence) / 2) + 0.25
# 100%|██████████| 70558/70558 [01:08<00:00, 1033.70it/s]

# %%
complete_T_IT.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'T_Profit', 'D_Profit', 'Loss',
#        'Defence_Target', 'Ideal_Target', 'Ideal_Target_Agressive',
#        'Dist_Bt_T_It', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
complete_T_IT.to_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Calculated_Data_Folders/Complete_Data_T_IT_P_L/Actual_target_loss.csv",index=False)

# %%
import pandas as pd
from tqdm import tqdm
import os

def apply_trading_logic(df):
    # Initialize the new columns with 0
    df['T_Profit'] = 0
    df['D_Profit'] = 0
    df['Loss'] = 0
    df['Ideal_Target_Buyer'] = 0
    df['Defence_Target_Buyer'] = 0
    df['Ideal_Target_Seller'] = 0
    df['Defence_Target_Seller'] = 0
    df['Defence_Target'] = 0
    df['Ideal_Target'] = 0
    df['Ideal_Target_Agressive'] = 0
    df['Dist_Bt_T_It'] = 0
    df['Dist_Bt_T_IAT'] = 0

    # Iterate over each row with tqdm for progress tracking
    for i in tqdm(range(len(df))):
        row = df.iloc[i]

        # Entry Value Check
        if row['Entry'] != 0:
            entry = row['Entry']
            defence = row['Defence']

            # Buyers Logic
            if row['BuyersInControlPrice'] != 0:
                # Defence Check
                low_future_rows = df.iloc[i+1:]['Low']
                matched_low_index = low_future_rows[low_future_rows == defence].index
                if not matched_low_index.empty:
                    matched_low_index = matched_low_index[0]
                    max_high = df.loc[i:matched_low_index, 'High'].max()
                    max_close = df.loc[i:matched_low_index, 'Close'].max()

                    df.loc[i, 'Ideal_Target_Buyer'] = max_close
                    df.loc[i, 'Ideal_Target_Agressive'] = max_high

                    # Target vs. Max High Value Comparison
                    if row['Target'] <= max_high:
                        df.loc[i, 'T_Profit'] = row['Target'] - entry
                    else:
                        stop = row['Stop']
                        if stop != 0:
                            df.loc[i, 'Defence_Target_Buyer'] = ((entry + defence) / 2) + 0.25
                            matched_stop_index = low_future_rows[low_future_rows == stop].index
                            if not matched_stop_index.empty:
                                matched_stop_index = matched_stop_index[0]
                                max_high_stop = df.loc[i:matched_stop_index, 'High'].max()
                                max_close_stop = df.loc[i:matched_stop_index, 'Close'].max()

                                # Defence Target vs. Max High Value Comparison
                                if df.loc[i, 'Defence_Target_Buyer'] <= max_high_stop:
                                    df.loc[i, 'D_Profit'] = df.loc[i, 'Defence_Target_Buyer'] - entry
                                else:
                                    df.loc[i, 'Loss'] = df.loc[i, 'Defence_Target_Buyer'] - entry

            # Sellers Logic
            if row['SellersInControlPrice'] != 0:
                # Defence Check
                high_future_rows = df.iloc[i+1:]['High']
                matched_high_index = high_future_rows[high_future_rows == defence].index
                if not matched_high_index.empty:
                    matched_high_index = matched_high_index[0]
                    min_low = df.loc[i:matched_high_index, 'Low'].min()
                    min_close = df.loc[i:matched_high_index, 'Close'].min()

                    df.loc[i, 'Ideal_Target_Seller'] = min_close
                    df.loc[i, 'Ideal_Target_Agressive'] = min_low

                    # Target vs. Min Low Value Comparison
                    if row['Target'] >= min_low:
                        df.loc[i, 'T_Profit'] = entry - row['Target']
                    else:
                        stop = row['Stop']
                        if stop != 0:
                            df.loc[i, 'Defence_Target_Seller'] = ((entry + defence) / 2) - 0.25
                            matched_stop_index = high_future_rows[high_future_rows == stop].index
                            if not matched_stop_index.empty:
                                matched_stop_index = matched_stop_index[0]
                                min_low_stop = df.loc[i:matched_stop_index, 'Low'].min()
                                min_close_stop = df.loc[i:matched_stop_index, 'Close'].min()

                                # Defence Target vs. Min Low Value Comparison
                                if df.loc[i, 'Defence_Target_Seller'] >= min_low_stop:
                                    df.loc[i, 'D_Profit'] = entry - df.loc[i, 'Defence_Target_Seller']
                                else:
                                    df.loc[i, 'Loss'] = df.loc[i, 'Defence_Target_Seller'] - entry

        # Additional Calculations
        df.loc[i, 'Ideal_Target'] = df.loc[i, 'Ideal_Target_Buyer'] + df.loc[i, 'Ideal_Target_Seller']
        df.loc[i, 'Defence_Target'] = df.loc[i, 'Defence_Target_Buyer'] + df.loc[i, 'Defence_Target_Seller']
        df.loc[i, 'Dist_Bt_T_It'] = abs(df.loc[i, 'Ideal_Target'] - row['Target'])
        df.loc[i, 'Dist_Bt_T_IAT'] = abs(df.loc[i, 'Ideal_Target_Agressive'] - row['Target'])

    # Drop unnecessary columns if they exist
    columns_to_drop = ["Ideal_Target_Buyer", "Ideal_Target_Seller", "Defence_Target_Buyer", "Defence_Target_Seller"]
    df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

    return df

def process_files(input_directory, output_directory):
    # Ensure the output directory exists
    os.makedirs(output_directory, exist_ok=True)

    # Process each CSV file in the input directory
    for filename in os.listdir(input_directory):
        if filename.endswith('.csv'):
            input_path = os.path.join(input_directory, filename)
            # Add prefix "Complete_" to the output file name
            output_path = os.path.join(output_directory, f"Complete_{filename}")

            # Read the input file
            df = pd.read_csv(input_path)

            # Convert 'Time Stamp' to datetime
            if 'Time Stamp' in df.columns:
                df['Time Stamp'] = pd.to_datetime(df['Time Stamp'], errors='coerce')

            # Drop the "Unnamed: 0" column if it exists
            if 'Unnamed: 0' in df.columns:
                df.drop(columns=['Unnamed: 0'], inplace=True)

            # Apply the trading logic
            df = apply_trading_logic(df)

            # Save the processed file to the output directory
            df.to_csv(output_path, index=False)
            print(f"Processed {filename} and saved to {output_path}")


# Example usage
output_directory = '/content/drive/MyDrive/Real_Trader_EDA_R1/ES_5min_data/Calculated_Data_Folders/Final_Data_T_IT_Pro_Loss'
process_files(data_folder, output_directory)
