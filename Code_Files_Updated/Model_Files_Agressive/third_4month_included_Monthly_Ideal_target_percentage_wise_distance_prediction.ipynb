# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import glob
pd.set_option('display.max_columns',40)
pd.set_option('display.max_rows', 300)  # Show all rows

os.chdir('/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/Updated_ES/dataset_set_3')
# Path to your data folder in Google Drive
data_folder = '/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/Updated_ES/dataset_set_3'

# List files in the specified folder to confirm access
folder_path = os.path.join(data_folder)  # Update 'path_to_your_data_folder' with your actual folder path
file_list = os.listdir(folder_path)
file_list
# Out:
# ['train_data_set_3.csv', 'test_data_set_3.csv']

# %%
train_cal_data = pd.read_csv("train_data_set_3.csv")

# %%
test_cal_data = pd.read_csv("test_data_set_3.csv")

# %%
print(train_cal_data.shape)
print(test_cal_data.shape)
# Out:
# (348549, 25)
# (18935, 25)

# %%
train_cal_data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target',
#        'Ideal_Target_Agressive', 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
test_cal_data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target',
#        'Ideal_Target_Agressive', 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
# 1. Count rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0
buyers_count = train_cal_data[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0)
].shape[0]


buyers_count_agressive = train_cal_data[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] == 0)
].shape[0]

# 2. Count rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0
sellers_count = train_cal_data[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0)
].shape[0]


sellers_count_agresssive = train_cal_data[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] == 0)
].shape[0]


# 5. Count rows where BuyersInControlPrice, Entry, Target, Ideal_Target are not equal to 0 AND Dist_Bt_T_IT is negative
buyers_negative_dist_count = train_cal_data[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0) &
    (train_cal_data['Dist_Bt_T_IAT'] < 0)
].shape[0]

# 6. Count rows where SellersInControlPrice, Entry, Target, Ideal_Target are not equal to 0 AND Dist_Bt_T_IT is positive
sellers_positive_dist_count = train_cal_data[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0) &
    (train_cal_data['Dist_Bt_T_IAT'] > 0)
].shape[0]

# 3. Count rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0 AND Target == Ideal_Target
buyers_target_equal_ideal_count = train_cal_data[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0) &
    (train_cal_data['Target'] == train_cal_data['Ideal_Target_Agressive'])
].shape[0]

# 4. Count rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0 AND Target == Ideal_Target
sellers_target_equal_ideal_count = train_cal_data[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0) &
    (train_cal_data['Target'] == train_cal_data['Ideal_Target_Agressive'])
].shape[0]

# Print the results
# Print the results
print(f"Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: {buyers_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: {sellers_count}")
print(f"Count of rows where BuyersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is negative: {buyers_negative_dist_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is positive: {sellers_positive_dist_count}")
print(f"Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: {buyers_target_equal_ideal_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: {sellers_target_equal_ideal_count}")
print(buyers_count_agressive,"buyers_count_agressive")
print(sellers_count_agresssive,"sellers_count_agressive")
# Out:
# Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: 47108
# Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: 45490
# Count of rows where BuyersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is negative: 9445
# Count of rows where SellersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is positive: 10044
# Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: 1474
# Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: 1415
# 1861 buyers_count_agressive
# 1580 sellers_count_agressive

# %%
# 1. For Buyer case: Fix condition to correctly group logical checks
train_cal_data.loc[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Target'] != 0) &
    (
        (train_cal_data['Ideal_Target'] <= train_cal_data['Target']) |
        ((train_cal_data['Ideal_Target_Agressive'] <= train_cal_data['Target']) &
         (train_cal_data['Ideal_Target_Agressive'] == 0) &
         (train_cal_data['Dist_Bt_T_IAT']<0))
        ),
    ['Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target', "Ideal_Target_Agressive", 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT']
] = 0


# # 2. For Seller case: Set specific columns to 0 where Ideal_Target or Ideal_Target_Aggressive >= Target
# train_cal_data.loc[
#     (train_cal_data['SellersInControlPrice'] != 0) &
#     (train_cal_data['Entry'] != 0) &
#     (train_cal_data['Target'] != 0) &
#     ((train_cal_data['Ideal_Target'] >= train_cal_data['Target']) |
#      (train_cal_data['Ideal_Target_Agressive'] >= train_cal_data['Target'])&
#      train_cal_data['Ideal_Target_Agressive'] == 0),
#     ['Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target', 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT']
# ] = 0

# %%
# 1. For Seller case: Fix condition to correctly group logical checks
train_cal_data.loc[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Target'] != 0) &
    (
        (train_cal_data['Ideal_Target'] >= train_cal_data['Target']) |
        (train_cal_data['Ideal_Target_Agressive'] >= train_cal_data['Target']) &
         (train_cal_data['Dist_Bt_T_IAT']>0)
        ),
    ['Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target', "Ideal_Target_Agressive", 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT']
] = 0

# %%
# 1. Count rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0
buyers_count = train_cal_data[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0)
].shape[0]


buyers_count_agressive = train_cal_data[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] == 0)
].shape[0]




# 2. Count rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0
sellers_count = train_cal_data[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0)
].shape[0]


sellers_count_agressive = train_cal_data[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] == 0)
].shape[0]


# 5. Count rows where BuyersInControlPrice, Entry, Target, Ideal_Target are not equal to 0 AND Dist_Bt_T_IT is negative
buyers_negative_dist_count = train_cal_data[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0) &
    (train_cal_data['Dist_Bt_T_IAT'] < 0)
].shape[0]

# 6. Count rows where SellersInControlPrice, Entry, Target, Ideal_Target are not equal to 0 AND Dist_Bt_T_IT is positive
sellers_positive_dist_count = train_cal_data[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0) &
    (train_cal_data['Dist_Bt_T_IAT'] > 0)
].shape[0]

# 3. Count rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0 AND Target == Ideal_Target
buyers_target_equal_ideal_count = train_cal_data[
    (train_cal_data['BuyersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0) &
    (train_cal_data['Target'] == train_cal_data['Ideal_Target_Agressive'])
].shape[0]

# 4. Count rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0 AND Target == Ideal_Target
sellers_target_equal_ideal_count = train_cal_data[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Defence'] != 0) &
    (train_cal_data['Target'] != 0) &
    (train_cal_data['Ideal_Target_Agressive'] != 0) &
    (train_cal_data['Target'] == train_cal_data['Ideal_Target_Agressive'])
].shape[0]

# Print the results
# Print the results
print(f"Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: {buyers_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: {sellers_count}")
print(f"Count of rows where BuyersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is negative: {buyers_negative_dist_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is positive: {sellers_positive_dist_count}")
print(f"Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: {buyers_target_equal_ideal_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: {sellers_target_equal_ideal_count}")
print(buyers_count_agressive,"buyers_count_agressive")
print(sellers_count_agressive,"sellers_count_agressive")
# Out:
# Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: 32134
# Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: 30051
# Count of rows where BuyersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is negative: 0
# Count of rows where SellersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is positive: 0
# Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: 0
# Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: 0
# 0 buyers_count_agressive
# 0 sellers_count_agressive

# %%
# 2. For Seller case: Set specific columns to 0 where Ideal_Target or Ideal_Target_Aggressive >= Target
train_cal_data.loc[
    (train_cal_data['SellersInControlPrice'] != 0) &
    (train_cal_data['Entry'] != 0) &
    (train_cal_data['Target'] != 0) &
     (train_cal_data['Ideal_Target_Agressive'] == 0),
    ['Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target', 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT']
] = 0

# %%
filtered_df_S = train_cal_data[(train_cal_data['SellersInControlPrice'] != 0) & (train_cal_data['Entry']!=0) & (train_cal_data['Dist_Bt_T_IAT']>0)].shape[0]

# %%
filtered_df_S
# Out:
# 0

# %%
filtered_df_B = train_cal_data[(train_cal_data['BuyersInControlPrice'] != 0) & (train_cal_data['Entry']!=0) & (train_cal_data['Dist_Bt_T_IAT']<0)].shape[0]

# %%
filtered_df_B
# Out:
# 0

# %%
# 1. Count rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0
buyers_count = test_cal_data[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0)
].shape[0]


buyers_count_agressive = test_cal_data[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] == 0)
].shape[0]

# 2. Count rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0
sellers_count = test_cal_data[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0)
].shape[0]


sellers_count_agresssive = test_cal_data[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] == 0)
].shape[0]


# 5. Count rows where BuyersInControlPrice, Entry, Target, Ideal_Target are not equal to 0 AND Dist_Bt_T_IT is negative
buyers_negative_dist_count = test_cal_data[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0) &
    (test_cal_data['Dist_Bt_T_IAT'] < 0)
].shape[0]

# 6. Count rows where SellersInControlPrice, Entry, Target, Ideal_Target are not equal to 0 AND Dist_Bt_T_IT is positive
sellers_positive_dist_count = test_cal_data[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0) &
    (test_cal_data['Dist_Bt_T_IAT'] > 0)
].shape[0]

# 3. Count rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0 AND Target == Ideal_Target
buyers_target_equal_ideal_count = test_cal_data[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0) &
    (test_cal_data['Target'] == test_cal_data['Ideal_Target_Agressive'])
].shape[0]

# 4. Count rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0 AND Target == Ideal_Target
sellers_target_equal_ideal_count = test_cal_data[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0) &
    (test_cal_data['Target'] == test_cal_data['Ideal_Target_Agressive'])
].shape[0]

# Print the results
# Print the results
print(f"Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: {buyers_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: {sellers_count}")
print(f"Count of rows where BuyersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is negative: {buyers_negative_dist_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is positive: {sellers_positive_dist_count}")
print(f"Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: {buyers_target_equal_ideal_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: {sellers_target_equal_ideal_count}")
print(buyers_count_agressive,"buyers_count_agressive")
print(sellers_count_agresssive,"sellers_count_agressive")
# Out:
# Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: 2104
# Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: 1973
# Count of rows where BuyersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is negative: 461
# Count of rows where SellersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is positive: 482
# Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: 54
# Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: 70
# 534 buyers_count_agressive
# 344 sellers_count_agressive

# %%
# 1. For Buyer case: Fix condition to correctly group logical checks
test_cal_data.loc[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Target'] != 0) &
    (
        (test_cal_data['Ideal_Target'] <= test_cal_data['Target']) |
        ((test_cal_data['Ideal_Target_Agressive'] <= test_cal_data['Target']) &
         (test_cal_data['Ideal_Target_Agressive'] == 0) &
         (test_cal_data['Dist_Bt_T_IAT']<0))
        ),
    ['Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target', "Ideal_Target_Agressive", 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT']
] = 0


# # 2. For Seller case: Set specific columns to 0 where Ideal_Target or Ideal_Target_Aggressive >= Target
# train_cal_data.loc[
#     (train_cal_data['SellersInControlPrice'] != 0) &
#     (train_cal_data['Entry'] != 0) &
#     (train_cal_data['Target'] != 0) &
#     ((train_cal_data['Ideal_Target'] >= train_cal_data['Target']) |
#      (train_cal_data['Ideal_Target_Agressive'] >= train_cal_data['Target'])&
#      train_cal_data['Ideal_Target_Agressive'] == 0),
#     ['Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target', 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT']
# ] = 0

# %%
# 1. For Seller case: Fix condition to correctly group logical checks
test_cal_data.loc[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Target'] != 0) &
    (
        (test_cal_data['Ideal_Target'] >= test_cal_data['Target']) |
        (test_cal_data['Ideal_Target_Agressive'] >= test_cal_data['Target']) &
         (test_cal_data['Dist_Bt_T_IAT']>0)
        ),
    ['Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target', "Ideal_Target_Agressive", 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT']
] = 0

# %%
# 1. Count rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0
buyers_count = test_cal_data[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0)
].shape[0]


buyers_count_agressive = test_cal_data[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] == 0)
].shape[0]

# 2. Count rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0
sellers_count = test_cal_data[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0)
].shape[0]


sellers_count_agresssive = test_cal_data[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] == 0)
].shape[0]


# 5. Count rows where BuyersInControlPrice, Entry, Target, Ideal_Target are not equal to 0 AND Dist_Bt_T_IT is negative
buyers_negative_dist_count = test_cal_data[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0) &
    (test_cal_data['Dist_Bt_T_IAT'] < 0)
].shape[0]

# 6. Count rows where SellersInControlPrice, Entry, Target, Ideal_Target are not equal to 0 AND Dist_Bt_T_IT is positive
sellers_positive_dist_count = test_cal_data[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0) &
    (test_cal_data['Dist_Bt_T_IAT'] > 0)
].shape[0]

# 3. Count rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0 AND Target == Ideal_Target
buyers_target_equal_ideal_count = test_cal_data[
    (test_cal_data['BuyersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0) &
    (test_cal_data['Target'] == test_cal_data['Ideal_Target_Agressive'])
].shape[0]

# 4. Count rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target are not equal to 0 AND Target == Ideal_Target
sellers_target_equal_ideal_count = test_cal_data[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Defence'] != 0) &
    (test_cal_data['Target'] != 0) &
    (test_cal_data['Ideal_Target_Agressive'] != 0) &
    (test_cal_data['Target'] == test_cal_data['Ideal_Target_Agressive'])
].shape[0]

# Print the results
# Print the results
print(f"Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: {buyers_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: {sellers_count}")
print(f"Count of rows where BuyersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is negative: {buyers_negative_dist_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is positive: {sellers_positive_dist_count}")
print(f"Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: {buyers_target_equal_ideal_count}")
print(f"Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: {sellers_target_equal_ideal_count}")
print(buyers_count_agressive,"buyers_count_agressive")
print(sellers_count_agresssive,"sellers_count_agressive")
# Out:
# Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: 1419
# Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero: 1222
# Count of rows where BuyersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is negative: 0
# Count of rows where SellersInControlPrice, Entry, Target, Ideal_Target_Agressive are not zero and Dist_Bt_T_IAT is positive: 0
# Count of rows where BuyersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: 0
# Count of rows where SellersInControlPrice, Entry, Defence, Target, Ideal_Target_Agressive are not zero and Target == Ideal_Target_Agressive: 0
# 0 buyers_count_agressive
# 0 sellers_count_agressive

# %%
# 2. For Seller case: Set specific columns to 0 where Ideal_Target or Ideal_Target_Aggressive >= Target
test_cal_data.loc[
    (test_cal_data['SellersInControlPrice'] != 0) &
    (test_cal_data['Entry'] != 0) &
    (test_cal_data['Target'] != 0) &
     (test_cal_data['Ideal_Target_Agressive'] == 0),
    ['Entry', 'Defence', 'Stop', 'Target', 'Ideal_Target', 'Dist_Bt_T_IT', 'Dist_Bt_T_IAT']
] = 0

# %%
filtered_df_S = test_cal_data[(test_cal_data['SellersInControlPrice'] != 0) & (test_cal_data['Entry']!=0) & (test_cal_data['Dist_Bt_T_IAT']>0)].shape[0]

# %%
filtered_df_S
# Out:
# 0

# %%
filtered_df_B = test_cal_data[(test_cal_data['BuyersInControlPrice'] != 0) & (test_cal_data['Entry']!=0) & (test_cal_data['Dist_Bt_T_IAT']<0)].shape[0]

# %%
filtered_df_B
# Out:
# 0

# %%
train_cal_data.drop(['Ideal_Target','Ideal_Target_Agressive','Dist_Bt_T_IT'], axis=1, inplace=True)
test_cal_data.drop(['Ideal_Target','Ideal_Target_Agressive','Dist_Bt_T_IT'], axis=1, inplace=True)

# %%
train_cal_data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
test_cal_data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
# train_cal_data.drop(columns=['Defence_Time', 'Defence_Time_Value'], inplace=True)
# test_cal_data.drop(columns=['Defence_Time', 'Defence_Time_Value'], inplace=True)

# %%
train_cal_data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
test_cal_data.columns
# Out:
# Index(['Time Stamp', 'Open', 'High', 'Low', 'Close', 'SellersLevel4',
#        'SellersLevel3', 'SellersLevel2', 'SellersLevel1', 'SellersLevel0',
#        'BuyersLevel0', 'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3',
#        'BuyersLevel4', 'BuyersInControlPrice', 'SellersInControlPrice',
#        'Entry', 'Defence', 'Stop', 'Target', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
train_cal_data.sample(10)
# Out:
#                  Time Stamp     Open     High      Low    Close  \
# 232963  2022-10-10 18:10:00  3968.25  3968.50  3966.00  3967.00
# 99382   2020-11-19 19:20:00  3865.00  3866.50  3863.75  3866.00
# 189439  2022-03-01 12:35:00  4660.50  4667.00  4656.25  4662.50
# 203737  2022-05-13 07:10:00  4331.25  4331.25  4328.75  4330.75
# 163763  2021-10-19 22:35:00  4855.00  4855.25  4854.50  4854.50
# 3901    2019-07-12 07:50:00  3292.50  3293.50  3292.25  3293.25
# 52644   2020-03-23 19:15:00  2565.50  2570.25  2559.75  2562.75
# 163745  2021-10-19 21:05:00  4858.50  4859.00  4857.50  4858.00
# 11208   2019-08-20 01:20:00  3209.00  3209.25  3208.75  3209.00
# 86541   2020-09-15 04:15:00  3693.50  3694.50  3691.25  3692.25
#
#         SellersLevel4  SellersLevel3  SellersLevel2  SellersLevel1  \
# 232963        3972.75        3971.25        3959.50        3958.50
# 99382         3865.25        3864.75        3863.75        3861.75
# 189439        4668.25        4660.25        4656.50        4655.75
# 203737        4330.00        4329.75        4323.00        4319.75
# 163763        4857.50        4855.75        4850.00        4844.00
# 3901          3293.50        3293.25        3292.50        3292.00
# 52644         2509.25        2508.75        2506.00        2504.25
# 163745        4859.00        4850.00        4844.00        4837.75
# 11208         3204.50        3204.00        3202.75        3201.25
# 86541         3693.25        3692.25        3681.00        3679.25
#
#         SellersLevel0  BuyersLevel0  BuyersLevel1  BuyersLevel2  BuyersLevel3  \
# 232963        3957.00       3951.00       3951.75       3962.50       3966.00
# 99382         3859.75       3875.75       3876.00       3877.00       3881.50
# 189439        4653.25       4676.25       4683.50       4684.75       4690.25
# 203737        4317.00       4318.50       4320.25       4324.75       4328.00
# 163763        4837.75       4850.00       4851.00       4851.50       4852.25
# 3901          3284.75       3284.25       3288.00       3292.00       3292.75
# 52644         2495.50       2473.75       2478.25       2502.00       2502.25
# 163745        4835.50       4850.00       4851.00       4851.50       4852.25
# 11208         3200.00       3202.50       3203.25       3204.25       3205.75
uyersLevel0  BuyersLevel1  BuyersLevel2  BuyersLevel3  BuyersLevel4  \
# 5691        5538.00       5540.25       5543.50       5546.25       5546.75
# 16152       5654.00       5655.00       5655.50       5656.00       5658.75
# 4938        5534.75       5535.25       5535.50       5546.75       5547.00
# 13131       5331.75       5333.00       5338.75       5340.75       5346.75
# 13363       5377.25       5378.25       5378.75       5381.00       5382.25
# 9463        5592.25       5593.00       5594.00       5595.25       5597.00
# 3794        5522.00       5527.00       5530.75       5532.25       5534.00
# 16040       5639.25       5643.75       5644.00       5645.50       5646.75
# 7023        5632.75       5633.00       5633.25       5633.50       5633.75
# 13504       5362.50       5362.75       5364.00       5368.00       5370.25
#
#        BuyersInControlPrice  SellersInControlPrice    Entry  Defence     Stop  \
# 5691                5551.50                   0.00     0.00     0.00     0.00
# 16152                  0.00                5640.75     0.00     0.00     0.00
# 4938                5550.00                   0.00     0.00     0.00     0.00
# 13131                  0.00                5337.75     0.00     0.00     0.00
# 13363                  0.00                5383.25     0.00     0.00     0.00
# 9463                5608.00                   0.00     0.00     0.00     0.00
# 3794                   0.00                5534.75  5534.75  5535.00  5535.25
# 16040               5647.75                   0.00  5647.75  5646.75  5645.50
# 7023                   0.00                5633.75  5633.75  5634.00  5634.25
# 13504                  0.00                5371.25     0.00     0.00     0.00
#
#         Target  Dist_Bt_T_IAT
# 5691      0.00           0.00
# 16152     0.00           0.00
# 4938      0.00           0.00
# 13131     0.00           0.00
# 13363     0.00           0.00
# 9463      0.00           0.00
# 3794   5534.00          -9.75
# 16040  5648.50          20.50
# 7023   5633.25        -513.25
# 13504     0.00           0.00

# %%
train_cal_data["Time Stamp"] = pd.to_datetime(train_cal_data["Time Stamp"])
test_cal_data["Time Stamp"] = pd.to_datetime(test_cal_data["Time Stamp"])

# %%
train_cal_data.set_index('Time Stamp', inplace=True)
test_cal_data.set_index('Time Stamp', inplace=True)

# %%
train_cal_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'SellersLevel4', 'SellersLevel3',
#        'SellersLevel2', 'SellersLevel1', 'SellersLevel0', 'BuyersLevel0',
#        'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3', 'BuyersLevel4',
#        'BuyersInControlPrice', 'SellersInControlPrice', 'Entry', 'Defence',
#        'Stop', 'Target', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
test_cal_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'SellersLevel4', 'SellersLevel3',
#        'SellersLevel2', 'SellersLevel1', 'SellersLevel0', 'BuyersLevel0',
#        'BuyersLevel1', 'BuyersLevel2', 'BuyersLevel3', 'BuyersLevel4',
#        'BuyersInControlPrice', 'SellersInControlPrice', 'Entry', 'Defence',
#        'Stop', 'Target', 'Dist_Bt_T_IAT'],
#       dtype='object')

# %%
print(train_cal_data.shape)
print(test_cal_data.shape)
# Out:
# (348549, 21)
# (18935, 21)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Step 1: Data Preparation - Define features and target from the training data
X_train = train_cal_data.drop(columns=['Dist_Bt_T_IAT'])  # Features from training data
y_train = train_cal_data['Dist_Bt_T_IAT']  # Target variable from training data

# Step 2: Prepare test data features and target
X_test = test_cal_data.drop(columns=['Dist_Bt_T_IAT'])  # Features from test data
y_test = test_cal_data['Dist_Bt_T_IAT']  # Target variable from test data

# %%
X_train.head()
# Out:
#                         Open     High      Low    Close  SellersLevel4  \
# Time Stamp
# 2019-06-23 18:30:00  3234.75  3235.75  3234.50  3235.75            0.0
# 2019-06-23 18:35:00  3235.75  3236.50  3235.25  3236.50            0.0
# 2019-06-23 18:40:00  3236.50  3236.50  3235.75  3236.00            0.0
# 2019-06-23 18:45:00  3236.00  3236.50  3236.00  3236.25            0.0
# 2019-06-23 18:50:00  3236.50  3237.00  3236.25  3236.50            0.0
#
#                      SellersLevel3  SellersLevel2  SellersLevel1  \
# Time Stamp
# 2019-06-23 18:30:00            0.0            0.0            0.0
# 2019-06-23 18:35:00            0.0            0.0            0.0
# 2019-06-23 18:40:00            0.0            0.0            0.0
# 2019-06-23 18:45:00            0.0            0.0            0.0
# 2019-06-23 18:50:00            0.0            0.0            0.0
#
#                      SellersLevel0  BuyersLevel0  BuyersLevel1  BuyersLevel2  \
# Time Stamp
# 2019-06-23 18:30:00            0.0           0.0           0.0           0.0
# 2019-06-23 18:35:00            0.0           0.0           0.0           0.0
# 2019-06-23 18:40:00            0.0           0.0           0.0           0.0
# 2019-06-23 18
dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Initialize the RandomForest model

rf_model = RandomForestRegressor(n_estimators=50, random_state=42,n_jobs=-1)  # Start with 0 estimators


rf_model.fit(X_train, y_train)

# Predict and evaluate
rf_y_pred = rf_model.predict(X_test)
rf_rmse = mean_squared_error(y_test, rf_y_pred, squared=False)
rf_mae = mean_absolute_error(y_test, rf_y_pred)
print(f"RandomForest RMSE: {rf_rmse}, MAE: {rf_mae}")
# Out:
# RandomForest RMSE: 46.83840755895846, MAE: 12.636811724320044
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predict on the unseen test data
rf_y_pred = rf_model.predict(X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, rf_y_pred)
mse = mean_squared_error(y_test, rf_y_pred)
rmse = mean_squared_error(y_test, rf_y_pred, squared=False)
r2 = r2_score(y_test, rf_y_pred)

# Display the metrics
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 12.6368
# Mean Squared Error (MSE): 2193.8364
# Root Mean Squared Error (RMSE): 46.8384
# R-squared (R²): 0.0976
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predict on the unseen test data
rf_y_pred = rf_model.predict(X_train)

# Calculate evaluation metrics
mae = mean_absolute_error(y_train, rf_y_pred)
mse = mean_squared_error(y_train, rf_y_pred)
rmse = mean_squared_error(y_train, rf_y_pred, squared=False)
r2 = r2_score(y_train, rf_y_pred)

# Display the metrics
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 1.8844
# Mean Squared Error (MSE): 159.8750
# Root Mean Squared Error (RMSE): 12.6442
# R-squared (R²): 0.9702
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Step 4: Visualization - Combine results into a DataFrame
rf_results_df = X_test.copy()
rf_results_df['Actual_100%_dis'] = y_test
rf_results_df['Predicted_100%_dis'] = rf_y_pred

# %%
rf_results_df
# Out:
#                         Open     High      Low    Close  SellersLevel4  \
# Time Stamp
# 2024-06-02 17:20:00  5363.75  5363.75  5363.75  5363.75         5296.5
# 2024-06-02 18:05:00  5364.00  5368.75  5357.00  5357.00         5296.5
# 2024-06-02 18:10:00  5357.25  5357.50  5354.75  5356.50         5296.5
# 2024-06-02 18:15:00  5356.75  5359.25  5356.25  5359.00         5296.5
# 2024-06-02 18:20:00  5359.25  5364.25  5359.00  5363.75         5296.5
# ...                      ...      ...      ...      ...            ...
# 2024-09-30 07:15:00  5780.00  5782.50  5780.00  5782.25         5658.0
# 2024-09-30 07:35:00  5780.25  5788.50  5780.00  5787.00         5658.0
# 2024-09-30 07:40:00  5786.75  5791.00  5786.00  5787.75         5658.0
# 2024-09-30 07:45:00  5787.50  5789.25  5784.00  5786.25         5658.0
# 2024-09-30 07:50:00  5786.25  5788.75  5785.75  5788.00         5658.0
#
#                      SellersLevel3  SellersLevel2  SellersLevel1  \
# Time Stamp
# 2024-06-02 17:20:00        5287.75        5284.50         5281.5
# 2024-06-02 18:05:00        5287.75        5284.50         5281.5
# 2024-06-02 18:10:00        5287.75        5284.50         5281.5
# 2024-06-02 18:15:00        5287.75        5284.50         5281.5
# 2024-06-02 18:20:00        5287.75        5284.50         5281.5
# ...                            ...            ...            ...
# 2024-09-30 07:15:00        5616.50        5614.75         5614.0
# 2024-09-30 07:35:00        5616.50        5614.75         5614.0
# 2024-09-30 07:40:00        5616.50        5614.75         5614.0
# 2024-09-30 07:45:00        5616.50        5614.75         5614.0
# 2024-09-30 07:50:00        5616.50        5614.75         5614.0
#
#                      SellersLevel0  BuyersLevel0  BuyersLevel1  BuyersLevel2  \
# Time Stamp
# 2024-06-02 17:20:00        5281.00       5281.50       5283.50       5286.75
# 2024-06-02 18:05:00        5281.00       5281.50       5283.50       5286.75
# 2024-06-02 18:10:00        5281.00       5281.50       5283.50       5286.75
# 2024-06-02 18:15:00        5281.00       5281.50       5283.50       5286.75
# 2024-06-02 18:20:00        5281.00       5281.50       5283.50       5286.75
# ...                            ...           ...           ...           ...
# 2024-09-30 07:15:00        5613.25       5775.25       5776.50       5777.25
# 2024-09-30 07:35:00        5613.25       5775.25       5776.50       5777.25
# 2024-09-30 07:40:00        5613.25       5776.50       5777.25       5778.00
# 2024-09-30 07:45:00        5613.25       5776.50       5777.25       5778.00
# 2024-09-30 07:50:00        5613.25       5776.50       5777.25       5778.00
#
#                      BuyersLevel3  BuyersLevel4  BuyersInControlPrice  \
# Time Stamp
# 2024-06-02 17:20:00        5289.0       5292.25               5363.75
# 2024-06-02 18:05:00        5289.0       5292.25                  0.00
# 2024-06-02 18:10:00        5289.0       5292.25                  0.00
# 2024-06-02 18:15:00        5289.0       5292.25               5359.00
# 2024-06-02 18:20:00        5289.0       5292.25               5363.75
# ...                           ...           ...                   ...
# 2024-09-30 07:15:00        5778.0       5780.00               5782.25
# 2024-09-30 07:35:00        5778.0       5780.00               5787.00
# 2024-09-30 07:40:00        5780.0       5786.00               5787.75
# 2024-09-30 07:45:00        5780.0       5786.00                  0.00
# 2024-09-30 07:50:00        5780.0       5786.00               5788.00
#
#                      SellersInControlPrice  Entry  Defence  Stop  Target  \
# Time Stamp
# 2024-06-02 17:20:00                   0.00    0.0      0.0   0.0     0.0
# 2024-06-02 18:05:00                5357.00    0.0      0.0   0.0     0.0
# 2024-06-02 18:10:00                5356.50    0.0      0.0   0.0     0.0
# 2024-06-02 18:15:00                   0.00    0.0      0.0   0.0     0.0
# 2024-06-02 18:20:00                   0.00    0.0      0.0   0.0     0.0
# ...                                    ...    ...      ...   ...     ...
# 2024-09-30 07:15:00                   0.00    0.0      0.0   0.0     0.0
# 2024-09-30 07:35:00                   0.00    0.0      0.0   0.0     0.0
# 2024-09-30 07:40:00                   0.00    0.0      0.0   0.0     0.0
# 2024-09-30 07:45:00                5786.25    0.0      0.0   0.0     0.0
# 2024-09-30 07:50:00                   0.00    0.0      0.0   0.0     0.0
#
#                      Actual_100%_dis  Predicted_100%_dis
# Time Stamp
# 2024-06-02 17:20:00              0.0                 0.0
# 2024-06-02 18:05:00              0.0                 0.0
# 2024-06-02 18:10:00              0.0                 0.0
# 2024-06-02 18:15:00              0.0                 0.0
# 2024-06-02 18:20:00              0.0                 0.0
# ...                              ...                 ...
# 2024-09-30 07:15:00              0.0                 0.0
# 2024-09-30 07:35:00              0.0                 0.0
# 2024-09-30 07:40:00              0.0                 0.0
# 2024-09-30 07:45:00              0.0                 0.0
# 2024-09-30 07:50:00              0.0                 0.0
#
# [18935 rows x 22 columns]

# %%
rf_results_df.to_csv("/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/Updated_ES/Model_results/Updated_ES_Exp_Agressive_Dataset3.csv")

# %%
import joblib
import os

# Define the specific path where you want to save the model
path = '/content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/Updated_ES/Model_pkl_files/'
filename = 'Exp_updated_ES_Agressive_third4month_Ideal_target_100%_distance_random_forest_model_ESDT.pkl'

# Create the directory if it doesn't exist
os.makedirs(path, exist_ok=True)

# Save the model to the specified path
joblib.dump(rf_model, os.path.join(path, filename))

print(f"Model saved successfully at {os.path.join(path, filename)}")
# Out:
# Model saved successfully at /content/drive/MyDrive/Real_Trader_EDA_R1/Indian_Stocks_5Nov24/Updated_data/Updated_ES/Model_pkl_files/Exp_updated_ES_Agressive_third4month_Ideal_target_100%_distance_random_forest_model_ESDT.pkl
